# %%
import os
import json
from bs4 import BeautifulSoup
import requests
from selenium.webdriver.common.by import By

# %%
res = requests.get(r"https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&sc=0kf%3Aexplvl(MID_LEVEL)jt(fulltime)%3B&vjk=2d96653fd7ce7276&advn=8134151690508319");

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

driver.get("https://www.browserstack.com/");

driver.findElement(By.id("signupModalButton")).click()

# driver.get("https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&vjk=decd09bef6817b59")

# page_elements = driver.find_elements(By.CLASS_NAME, 'jcs-JobTitle')

# page_elements[2].click()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 101.0.4951
# [WDM] - Get LATEST chromedriver version for 101.0.4951 google-chrome
# [WDM] - Driver [/Users/raghavbansal/.wdm/drivers/chromedriver/mac64_m1/101.0.4951.41/chromedriver] found in cache
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [47], in <cell line: 9>()
#       6 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#       8 driver.get("https://www.browserstack.com/");
# ----> 9 driver.findElement(By.id("signupModalButton")).click()
#
# AttributeError: 'WebDriver' object has no attribute 'findElement'

# %%
page_elements = driver.find_elements(By.CLASS_NAME, 'jcs-JobTitle')
test_text;

# %%
driver.get("https://www.browserstack.com/");
driver.findElement(By.id("signupModalButton")).click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 driver.get("https://www.browserstack.com/");
#       2 driver.findElement(By.id("signupModalButton")).click()
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.get(self, url)
#     438 def get(self, url: str) -> None:
#     439     """
#     440     Loads a web page in the current browser session.
#     441     """
# --> 442     self.execute(Command.GET, {'url': url})
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=101.0.4951.64)
# Stacktrace:
# 0   chromedriver                        0x00000001052a49a0 chromedriver + 4426144
# 1   chromedriver                        0x000000010523e798 chromedriver + 4007832
# 2   chromedriver                        0x0000000104e9acc4 chromedriver + 191684
# 3   chromedriver                        0x0000000104e8b77c chromedriver + 128892
# 4   chromedriver                        0x0000000104e85f94 chromedriver + 106388
# 5   chromedriver                        0x0000000104ef1e64 chromedriver + 548452
# 6   chromedriver                        0x0000000104ebecf4 chromedriver + 339188
# 7   chromedriver                        0x000000010527b7d0 chromedriver + 4257744
# 8   chromedriver                        0x000000010527f580 chromedriver + 4273536
# 9   chromedriver                        0x00000001052836c4 chromedriver + 4290244
# 10  chromedriver                        0x000000010527fcf8 chromedriver + 4275448
# 11  chromedriver                        0x000000010525fb38 chromedriver + 4143928
# 12  chromedriver                        0x000000010529721c chromedriver + 4370972
# 13  chromedriver                        0x0000000105297380 chromedriver + 4371328
# 14  chromedriver                        0x00000001052ab154 chromedriver + 4452692
# 15  libsystem_pthread.dylib             0x00000001901e1240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001901dc024 thread_start + 8

# %%
element[0].click()

# %%
for element in page_elements:
    element.click();
    test_text = driver.page_source
    s = driver.find_element_by_id("jobDescriptionText")
    text = driver.execute_script("return arguments[0].innerHTML;",s)
    print(text)
# Out:
# /var/folders/dk/x6xr9ng103sfssc512l2rrlw0000gn/T/ipykernel_95564/2558450541.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   s = driver.find_element_by_id("jobDescriptionText")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
#       2 element.click();
#       3 test_text = driver.page_source
# ----> 4 s = driver.find_element_by_id("jobDescriptionText")
#       5 text = driver.execute_script("return arguments[0].innerHTML;",s)
#       6 print(text)
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:478, in WebDriver.find_element_by_id(self, id_)
#     457 """Finds an element by id.
#     458
#     459 :Args:
#    (...)
#     471         element = driver.find_element_by_id('foo')
#     472 """
#     473 warnings.warn(
#     474     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     475     DeprecationWarning,
#     476     stacklevel=2,
#     477 )
# --> 478 return self.find_element(by=By.ID, value=id_)
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1248     by = By.CSS_SELECTOR
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="jobDescriptionText"]"}
#   (Session info: chrome=101.0.4951.64)
# Stacktrace:
# 0   chromedriver                        0x00000001006f49a0 chromedriver + 4426144
# 1   chromedriver                        0x000000010068e798 chromedriver + 4007832
# 2   chromedriver                        0x00000001002eacc4 chromedriver + 191684
# 3   chromedriver                        0x00000001003198d4 chromedriver + 383188
# 4   chromedriver                        0x0000000100342648 chromedriver + 550472
# 5   chromedriver                        0x000000010030ecf4 chromedriver + 339188
# 6   chromedriver                        0x00000001006cb7d0 chromedriver + 4257744
# 7   chromedriver                        0x00000001006cf580 chromedriver + 4273536
# 8   chromedriver                        0x00000001006d36c4 chromedriver + 4290244
# 9   chromedriver                        0x00000001006cfcf8 chromedriver + 4275448
# 10  chromedriver                        0x00000001006afb38 chromedriver + 4143928
# 11  chromedriver                        0x00000001006e721c chromedriver + 4370972
# 12  chromedriver                        0x00000001006e7380 chromedriver + 4371328
# 13  chromedriver                        0x00000001006fb154 chromedriver + 4452692
# 14  libsystem_pthread.dylib             0x00000001901e1240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001901dc024 thread_start + 8

# %%
soup = BeautifulSoup(test_text, "html.parser")
soup.body
# Out:
# <body class="janus ltr miniRefresh jasxrefreshcombotst desktopAurora" data-tn-application="jasx" data-tn-olth="41be357fa1c7dc26c5ee98836f8950b3" data-tn-originlogid="1g4bflk4qq033801" data-tn-originlogtype="jobsearch">
# <div aria-label="skip" id="accessibilityBanner" role="navigation"><span id="accessibilityText">Skip to <!-- This is translated before reaching this state --><a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">Job Postings</a>, <!-- This is translated before reaching this state --><a class="accessibilityMenu" href="#text-input-what" id="skipToSearch">Search</a></span></div><script type="text/javascript">
# createTabBar('1g4bflk4qq033801');
# </script>
# <script>
# var bta = true;
# var a11yTwoPaneEnabled = true;
# var ltr = true;
# var vjsExhibitionModel = new indeed.vjsExhibition('auxCol', a11yTwoPaneEnabled, ltr, true);
# var vjsStable = true;
# //For SERP jobs, the scope of these job are document
# var showDebug = false;
# var sd = showDebug ? '1' : undefined;
# var viewJobOnSerp = new indeed.vjs('1g4bflk4qq033801', 'vjs', document, vjsExhibitionModel, sd, false, bta, a11yTwoPaneEnabled, false);
# var vjk = viewJobOnSerp.getVJK();
# var vjFrom = viewJobOnSerp.getFrom();
# var vjTk = viewJobOnSerp.getTk();
# var indconvtk = '';
# var vjUrl = viewJobOnSerp.vjUrl(vjk, vjFrom, vjTk, indconvtk);
# var showVjOnSerp = vjsStable;
# var zrp = false;
# var viewportTooSmall = true ? window.innerWidth < 960 : window.innerWidth < 1200;
# if ((zrp || !showVjOnSerp || viewportTooSmall) && vjUrl) {
# window.location.replace(vjUrl);
# } else if (showVjOnSerp) {
# initializeTwoPane();
# }
# function initializeTwoPane() {
# var jobKeysWithInfo = {};
#
# jobKeysWithInfo['4648517a71e4f182'] = true;
#
# jobKeysWithInfo['334710800248d3cb'] = true;
#
# jobKeysWithInfo['b3ac8952187c7f38'] = true;
#
# jobKeysWithInfo['8bdb0a9c1b4b6f33'] = true;
#
# jobKeysWithInfo['4ce542216e4493e3'] = true;
#
# jobKeysWithInfo['7a7d0fc7c11581d2'] = true;
#
# jobKeysWithInfo['b8a2315508208a9f'] = true;
#
# jobKeysWithInfo['286fec0793307370'] = true;
#
# jobKeysWithInfo['c4a1b9ab34e319b4'] = true;
#
# jobKeysWithInfo['c6a21c9367737e90'] = true;
#
# jobKeysWithInfo['529083e990483fa8'] = true;
#
# jobKeysWithInfo['950cd0b4e44bb59e'] = true;
#
# jobKeysWithInfo['0d2290656458e437'] = true;
#
# jobKeysWithInfo['1a1a45797a9c9ed2'] = true;
#
# jobKeysWithInfo['df0232a2effb091d'] = true;
#
# if (vjk && !jobKeysWithInfo.hasOwnProperty(vjk)) {
# jobKeysWithInfo[vjk] = true;
# }
# if (false) {
# viewJobOnSerp.preloadDescs(jobKeysWithInfo);
# }
# viewJobOnSerp.browserNavigationHandler();
# window.bindAndRender = function () {
# if (showVjOnSerp) {
# window['2paneEnabled'] = true;
# viewJobOnSerp.bindJobKeys(jobKeysWithInfo);
# if (vjUrl) {
# function renderJob () {
# viewJobOnSerp.renderOnJobKey(vjk, 'vjs', '1g4bflk4qq033801', '', undefined, undefined, function () {
# window.location.replace(vjUrl);
# }, function() {
#
# restore('savedjobs');
#
# }, true, 'https://m5.apply.indeed.com');
# }
# var mosaicJobcards = document.getElementById('mosaic-provider-jobcards');
# if (!!mosaicJobcards) {
# window.mosaic.onMosaicApiReady(function (initialization) {
# initialization['mosaic-provider-jobcards'].then(renderJob);
# });
# } else {
# renderJob();
# }
# }
# }
# };
# }
# </script>
# <script id="_indeed_gnav_config" type="application/json">{"isEmployer":false,"isMobile":false,"desktopPageLinks":[{"text":"Find jobs","href":"https://www.indeed.com/","dataHref":"https://www.indeed.com/?from=gnav-jobsearch--jasx","isHighlighted":true,"dataGnavElementName":"FindJobs"},{"text":"Company reviews","href":"https://www.indeed.com/companies","dataHref":"https://www.indeed.com/companies?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"CompanyReviews"},{"text":"Find salaries","href":"https://www.indeed.com/career/salaries","dataHref":"https://www.indeed.com/career/salaries?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"FindSalaries"}],"resumeLink":{"text":"Upload your resume","href":"https://www.indeed.com/promo/resume","dataHref":"https://www.indeed.com/promo/resume?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"UploadYourResume"},"skipNavLinkModel":{"href":"#gnav-header-end","text":"Skip to main content","targetText":"Start of main content","dataGnavElementName":"SkipNav"},"variantToggleLink":{"text":"Employers / Post Job","href":"https://www.indeed.com/hire?co=US\u0026hl=en","dataHref":"https://www.indeed.com/hire?co=US\u0026hl=en\u0026from=gnav-menu-jobsearch--jasx\u0026ikw=gnav-header-hire\u0026isid=employerlink-US","dataGnavElementName":"EmployersPostJob"},"country":"US","logoHref":"/?from=gnav-jobsearch--jasx","logoName":"ukraine","appName":"jobsearch--jasx","shouldReduceRightMargin":false,"inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-jobsearch--jasx\u0026gnavTK=1g4bflk4sqt6s800\u0026tk=\u0026co=US\u0026hl=en\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-jobsearch--jasx\u0026gnavTK=1g4bflk4sqt6s800\u0026tk=\u0026co=US\u0026hl=en","logRoute":"https://t.indeed.com/gnav/log?from=jobsearch--jasx-serp\u0026parentLogId=1g4bflk4sqt6s800\u0026hostAppTk=","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isInboxTestActive":false,"isShowInboxIcon":false,"inboxTestBucket":-1,"selectedIcon":"","shouldLowerNavIconMinWidth":true,"shouldReduceNavIconMargins":false,"inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","notificationApiHref":"https://www.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-jobsearch--jasx\u0026gnavTK=1g4bflk4sqt6s800\u0026tk=","notificationHref":"https://www.indeed.com/notifications?from=gnav-util-jobsearch--jasx\u0026gnavTK=1g4bflk4sqt6s800\u0026tk=\u0026hl=en","isShowNotificationIcon":false,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","myjobsApiHref":"","myjobsHref":"https://myjobs.indeed.com?from=gnav-util-jobsearch--jasx\u0026gnavTK=1g4bflk4sqt6s800\u0026tk=\u0026co=US\u0026hl=en","myjobsLogTuple":"gnavMyjobs:5d9eaad2bbc69a980218f0a8aa03ae77","isMyjobsTestActive":false,"isShowMyjobsIcon":false,"myjobsTestBucket":-1,"myjobsLogType":"gnavMyjobs","myjobsLth":"5d9eaad2bbc69a980218f0a8aa03ae77","isOnlineStatusActive":false,"onlineStatusApiHref":"https://employers.indeed.com/api/v2/messaging/onlinestatus/jobseeker?indeedcsrftoken=\u0026indeedClientApplication=gnav\u0026isClosed=false","signalsLogRoute":"https://t.indeed.com/signals/v1/log?from=jobsearch--jasx-serp\u0026parentLogId=1g4bflk4sqt6s800\u0026hostAppTk=","serviceRequestLogUID":"1g4bflk4sqt6s800","hostAppTk":"","canonicalPageId":"","applicationId":"jobsearch--jasx","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","clickLogType":"gnavClick","clickLth":"fa8b0aff9499e52dd7e9215032d9ad9f","pageSpeedLogType":"gnavPageSpeed","pageSpeedLth":"12783140239867f5afc3bd80a743e013","dwellTimeLogType":"gnavDwellTime","dwellTimeLth":"e415e44ee819f056fc4675c1b0373740","clickstreamEnabled":false,"cli ...
# <script>
#             if (window.performance !== undefined && performance.mark !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:start');
#             }
#         </script><link crossorigin="anonymous" href="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/header/jobseekerHeader.08a4619ac8e126815b21.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://fonts.googleapis.com/css2?family=Noto+Sans%3Aital%2Cwght%400%2C400%3B0%2C700%3B1%2C400%3B1%2C700&amp;display=swap" rel="stylesheet" type="text/css"/>
# <script>
#             if (window.performance !== undefined && performance.mark !== undefined && performance.measure !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:end');
#                 performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#             }
#         </script><nav aria-label="Primary" class="gnav" id="gnav-main-container"><div data-gnav-region="Main"><div class="gnav-header-1fosl13 e37uo190"><div class="gnav-header-1dk5aj e37uo190"><button class="gnav-header-lneyc9 e8ju0x51" data-gnav-element-name="SkipNav"><span>Skip to main content</span></button><a aria-label="Indeed Home" class="gnav-Logo gnav-header-10pmpdd emf9s7v0" data-gnav-element-name="Logo" href="/?from=gnav-jobsearch--jasx" id="indeed-globalnav-logo" title=""><div aria-hidden="true" class="gnav-Logo-icon"><svg fill="none" height="20" viewbox="0 0 75 20" width="75" xmlns="http://www.w3.org/2000/svg"><mask height="20" id="mask958290" maskunits="userSpaceOnUse" style="mask-type:alpha" width="75" x="0" y="0"><g clip-path="url(#cp958290)"><path clip-rule="evenodd" d="M74.6136 3.45837C74.3482 3.16077 73.9932 3.01037 73.5135 3.01037C73.0338 3.01037 72.6676 3.16877 72.4118 3.49677C72.1575 3.81357 72.0248 4.29037 72.0248 4.91437V9.43757C71.4348 8.80237 70.8223 8.34637 70.2003 8.03917C69.8118 7.85197 69.3545 7.71277 68.8444 7.64237C68.5486 7.60237 68.2431 7.58157 67.9074 7.58157C66.3483 7.58157 65.0851 8.11757 64.1161 9.18957C63.1583 10.2616 62.6786 11.7496 62.6786 13.6616C62.6786 14.5656 62.8017 15.4088 63.0448 16.1816C63.291 16.9544 63.6348 17.6296 64.1049 18.204C64.5734 18.78 65.1347 19.2152 65.7759 19.5336C66.4171 19.8408 67.111 19.9992 67.8642 19.9992C68.2096 19.9992 68.5358 19.9704 68.8412 19.9112C69.0458 19.8808 69.2377 19.8312 69.4328 19.7704C69.9109 19.612 70.3602 19.3848 70.768 19.0968C71.1853 18.7992 71.6043 18.412 72.0216 17.9464V18.244C72.0216 18.8088 72.1639 19.236 72.4389 19.5432C72.7252 19.8408 73.0817 19.9992 73.5087 19.9992C73.9468 19.9992 74.3034 19.8504 74.5784 19.564C74.8519 19.2664 74.9958 18.8296 74.9958 18.2456V4.75757C75.0006 4.19117 74.8678 3.75437 74.6136 3.45837ZM71.4444 15.9352C71.1693 16.5096 70.8016 16.9368 70.3538 17.2152C69.8949 17.4936 69.3944 17.6312 68.8444 17.6312H68.8348C68.2831 17.6312 67.7842 17.4824 67.3253 17.196C66.8664 16.8984 66.5002 16.4616 66.2364 15.8872C65.9725 15.3016 65.8398 14.5976 65.8398 13.764C65.8398 12.98 65.9613 12.2872 66.2172 11.7016C66.4618 11.1064 66.8184 10.6504 67.2677 10.3336C67.7267 10.0056 68.2367 9.85677 68.8156 9.85677H68.846C69.3864 9.85677 69.8853 10.0152 70.3442 10.3224C70.8032 10.6296 71.1693 11.0776 71.4444 11.6616C71.7194 12.2472 71.8521 12.9512 71.8521 13.764C71.8521 14.636 71.7194 15.3608 71.4444 15.9352ZM61.5481 16.0648C61.3546 15.8968 61.0892 15.8072 60.763 15.8072C60.4672 15.8072 60.2433 15.8776 60.0802 16.0056C59.682 16.3624 59.367 16.6504 59.1208 16.8584C58.8777 17.0568 58.6011 17.2552 58.3069 17.4424C58.0223 17.6216 57.7153 17.7608 57.4114 17.8408C57.0948 17.9288 56.759 17.9688 56.3817 17.9688C56.3001 17.9688 56.2186 17.9688 56.1466 17.9592C55.6765 17.9304 55.24 17.8008 54.8434 17.5624C54.3733 17.2952 54.0071 16.9 53.7209 16.3832C53.4459 15.8472 53.3036 15.2328 53.294 14.5384H59.439C60.2641 14.5384 60.9053 14.4184 61.3546 14.2008C61.8135 13.9624 62.0374 13.4664 62.0374 12.7032C62.0374 11.8696 61.8135 11.0568 61.3754 10.2536C60.9373 9.45837 60.2849 8.80397 59.399 8.29997C58.5212 7.79437 57.4722 7.54637 56.2394 7.54637H56.1482C55.2416 7.55597 54.4053 7.70637 53.6618 7.98317C52.8878 8.28077 52.2338 8.70797 51.6934 9.25197C51.1753 9.80717 50.7675 10.4712 50.4925 11.2456C50.2175 12.02 50.0736 12.8632 50.0736 13.764C50.0736 15.6888 50.6348 17.196 51.7557 18.316C52.8143 19.3784 54.2822 19.9336 56.1466 19.9928C56.249 20.0024 56.3593 20.0024 56.4728 20.0024C57.3491 20.0024 58.1326 19.8936 58.8154 19.6664C59.4982 19.4376 60.0594 19.1592 60.5087 18.8232C60.9548 18.476 61.2922 18.1192 61.5161 17.7528C61.74 17.3864 61.8535 17.0584 61.8535 16.7896C61.8535 16.4808 61.7528 16.2328 61.5481 16.0648ZM54.2118 10.46C54.7123 9.93357 55.3535 9.67597 56.1386 9.67597H56.1498C56.9637 9.67597 57.6273 9.93357 58.1262 10.4488C58.6267 10.9656 58.9209 11.7496 58.9929 12.7992H53.2956C53.3963 11.7688 53.7033 10.9848 54.2118 10.46ZM48.1676 15.8056C47.8621 15.8056 4 ...
# //# sourceMappingURL=runtime.bd437239084a0f0f539f.js.map</script><script>(self.webpackChunkgnavInline=self.webpackChunkgnavInline||[]).push([[686],{1e3:function(o,n,e){e.p=window._INDEED_GNAV.scriptLoaderConfig.publicPath,window._INDEED_GNAV.onScriptLoadersReady||(window._INDEED_GNAV.onScriptLoadersReady=function(){for(var o=arguments.length,n=new Array(o),e=0;e<o;e++)n[e]=arguments[e];window._INDEED_GNAV.onScriptLoadersReady.q.push(n)},window._INDEED_GNAV.onScriptLoadersReady.q=[]),function o(n){if(window._INDEED_GNAV.onScriptLoadersReady.q){var e=document.createElement("script");e.async=!0,e.src=window._INDEED_GNAV.scriptLoaderConfig.sharedepsLoadersUrl,e.crossOrigin="anonymous",e.onerror=function(e){var r=n-1;if(r>0)o(r);else{var c,a,t,i,d,s=window._INDEED_GNAV.scriptLoaderConfig,l=(null===(c=e.error)||void 0===c?void 0:c.name)||"SharedepsShimLoaderError",p=(null===(a=e.error)||void 0===a?void 0:a.message)||e.message||"Failed to fetch & execute the sharedeps loader from the shim",u=(null===(t=e.error)||void 0===t?void 0:t.toString())||"".concat(l,": ").concat(p),E=null===(i=(null===(d=e.error)||void 0===d?void 0:d.stack)||"event: ".concat(e.filename,":").concat(e.lineno,":").concat(e.colno,"\nonerror: ").concat((new Error).stack))||void 0===i?void 0:i.substring(0,1e3),m=document.createElement("script");m.async=!0,m.crossOrigin="anonymous",m.src="".concat(s.logRoute,"&logType=").concat(s.jsErrorLogType,"&lth=").concat(s.jsErrorLth,"&name=").concat(l,"&message=").concat(encodeURIComponent(p),"&toString=").concat(encodeURIComponent(u),"&stack=").concat(encodeURIComponent(E)),document.body.appendChild(m)}},document.body.appendChild(e)}}(3)}},function(o){var n;n=1e3,o(o.s=n)}]);
# //# sourceMappingURL=sharedepsShim.62bbd7efd68817509aee.js.map</script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/dist/inline/sharedepsLoaders.db961aa623e126428d4a.js"></script><script>window._INDEED_GNAV.onScriptLoadersReady('loadRemoteModuleAfterDcl',{"prereqUrls":["https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/inline/mainHeader.cc480cc48f2e38a69eff.js"],"urls":["https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/header/remoteEntry.555b461c01a09cdf8c9f.js"],"scope":"gnavHeaderModule","module":"./jobseekerHeader"})</script><div id="gnav-script-contents"><template data-json='{"init":{"dsn":"https://0252655a41544fd28ae41f8b8ff36917@sentry.indeed.com/44849"},"isEnabled":true,"tags":{"appName":"jobsearch--jasx"},"ctk":"1g4bflk2hr0is800"}' id="sentry-json" style="display: none"></template>
# <script>
# window.IndeedSentry = window.IndeedSentry || {};
# window.IndeedSentry.preInitErrors = [];
# window.IndeedSentry.preInitErrorCatcher = function (error) {
#     window.IndeedSentry.preInitErrors.push(error);
# };
# window.addEventListener("error", window.IndeedSentry.preInitErrorCatcher);
# </script>
# <script>window._INDEED_GNAV.onScriptLoadersReady('loadScriptsInOrderAsyncAfterDcl',["https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?2"])</script>
# <script>
#                 window.signals_transport = window.signals_transport || {
#                     emitSignal: function(data){
#                         window.signals_transport_tmp = window.signals_transport_tmp || [];
#                         if (window.signals_transport_tmp.length < 1000) {
#                             window.signals_transport_tmp.push(data);
#                         }
#                     }
#                 };
#             </script>
# </div><style type="text/css">
# #jobsearch_nav {
# border-spacing: 0;
# }
# #jobsearch_nav td {
# padding: 0;
# }
# iframe { display:block; }
# #jobalerts .member { z-index: 1; }
# #jobsearch_nav .MosaicProviderRichSearchDaemon {
# margin-top: 15px;
# }
# #jobsearch_nav_body > tr,
# #jobsearch_nav_body > tr > td {
# display: block;
# }
# </style>
# <span id="hidden_colon" style="display:none">:</span>
# <table class="centered" id="jobsearch_nav" role="banner"><tbody id="jobsearch_nav_body"><tr>
# <td><div class="mosaic MosaicProviderRichSearchDaemon mosaic-provider-hydrated" id="MosaicProviderRichSearchDaemon"><div class="i-unmask" role="search"><div class="yosegi-InlineWhatWhere"><form action="/jobs?q=information%20technology&amp;l=San%20Francisco%2C%20CA" class="yosegi-InlineWhatWhere-form" id="jobsearch" method="get"><div class="yosegi-InlineWhatWhere-searchBox"><div class="yosegi-EmbeddedLabelInput yosegi-InlineWhatWhere-what"><div><div class="icl-TextInputClearable"><div class="icl-TextInput"><div class="icl-TextInput-labelWrapper"><label class="icl-TextInput-label" for="text-input-what" id="label-text-input-what" tabindex="-1">What</label></div><div class="icl-TextInput-wrapper"><input aria-invalid="false" aria-labelledby="label-text-input-what" aria-owns="text-input-what-suggestion-list" autocomplete="off" class="icl-TextInput-control icl-TextInput-control--withIconRight" id="text-input-what" name="q" placeholder="Job title, keywords, or company" type="text" value="information technology"/><span aria-hidden="true" class="icl-TextInput-icon iconRight"><span aria-hidden="true" class=""><svg aria-hidden="true" fill="none" height="20" width="21" xmlns="http://www.w3.org/2000/svg"><defs></defs><path clip-rule="evenodd" d="M11.4038 12.3048C10.7084 12.7451 9.88397 13 9 13c-2.48528 0-4.5-2.0147-4.5-4.5C4.5 6.01472 6.51472 4 9 4c2.4853 0 4.5 2.01472 4.5 4.5 0 .87711-.2509 1.6956-.6849 2.3876l3.5089 3.5089c.1952.1953.1952.5119 0 .7071l-.7071.7072c-.1953.1952-.5119.1952-.7071 0l-3.506-3.506zM11.5 8.5c0 1.38071-1.1193 2.5-2.5 2.5-1.38071 0-2.5-1.11929-2.5-2.5S7.61929 6 9 6c1.3807 0 2.5 1.11929 2.5 2.5z" fill="#767676" fill-rule="evenodd"></path></svg></span></span></div></div></div><div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px"><div id="text-input-what-suggestion-list"><div class="icl-Autocomplete-ariaResultsAvailableWrapper" style="border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px"><span aria-atomic="true" aria-live="polite" class="icl-Autocomplete-ariaResultsAvailable" role="status"></span></div><div class="icl-Autocomplete-ariaResultsAvailableWrapper" style="border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px"><span aria-atomic="true" aria-live="polite" class="icl-Autocomplete-ariaResultsAvailable" role="status"></span></div></div></div></div></div><div class="yosegi-EmbeddedLabelInput yosegi-InlineWhatWhere-where"><div><div class="icl-TextInputClearable"><div class="icl-TextInput"><div class="icl-TextInput-labelWrapper"><label class="icl-TextInput-label" for="text-input-where" id="label-text-input-where" tabindex="-1">Where</label></div><div class="icl-TextInput-wrapper"><input aria-invalid="false" aria-labelledby="label-text-input-where" aria-owns="text-input-where-suggestion-list" autocomplete="off" class="icl-TextInput-control icl-TextInput-control--withIconRight" id="text-input-where" name="l" placeholder="City, state, zip code, or “remote”" type="text" value="San Francisco, CA"/><span aria-hidden="true" class="icl-TextInput-icon iconRight"><span aria-hidden="true" class=""><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><defs></defs><path clip-rule="evenodd" d="M5.81104 8.2c0-2.322 1.87303-4.2 4.18889-4.2 2.31587 0 4.18887 1.878 4.18887 4.2 0 2.581-2.8123 6.1691-3.8282 7.3811-.1906.2274-.5307.2274-.72131 0C8.62332 14.3691 5.81104 10.781 5.81104 8.2zm4.1889 2.0029c1.10456 0 1.99996-.89545 1.99996-2.00002 0-1.10457-.8954-2-1.99996-2-1.10457 0-2 .89543-2 2s.89543 2.00002 2 2.00002z" fill="#767676" fill-rule="evenodd"></path></svg></span></span></div></div></div><div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px"><div id="text-input-where-suggestion-list"><div class="icl-Autocomplete-ariaResultsAvailableWrapper" style="border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow: ...
# <script type="text/javascript">
# function rclk(el,jobdata,oc,sal) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1g4bflk4qq033801&from=web&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvGRc6T1oNz2SAHbLghCKroe57kazNLugS_UXtncgnDZ0NKir76bA2GrFQRBNm1QEB1-Jj38oIum1QKAtVjE02ZIfQNXtO-YxCrxr5LU_Uavhy3hmm6XDilJxhwO_97zk9WsehctWoWu5vs2h7okCa1Q&ts=1653947945114&sal='+sal+ocstr+'"; path=/'; return true;}
#
# function vjrclk(jk, qd, rd, oc, vjk, vjtk, jobsearchTk) {
# var ocstr = oc ? '&onclick=1' : '';
# var jobsearchTk = jobsearchTk ? jobsearchTk : '';
# document.cookie = 'RCLK="jk=' + jk + '&vjtk=' + vjtk + '&jobsearchTk=' + jobsearchTk + '&rd=' + rd + '&qd=' + qd + '&ts=' + new Date().getTime() + ocstr + '"; path=/';
# return true;
# }
#
# function thirdpartysignin(href, vjk, vjtk, jobsearchTk) {
#
# var doc = new DOMParser().parseFromString(href, "text/html");
# var trackingURL = doc.documentElement.textContent;
# var trackingImage = new Image();
# trackingImage.src = trackingURL + '&vjs=2' + '&tk=' + vjtk + '&jobsearchTk=' + jobsearchTk;
# var url = '/thirdpartysignin' + window.location.search + '&jk=' + vjk + '&vjtk=' + vjtk + '&tk=' + vjtk + '&viewtype=embedded';
# window.open(url, '_blank', 'noopener');
# }
#
# function zrprclk(el,jobdata,oc) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1g4bflk4qq033801&from=reconzrp&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvGRc6T1oNz2SAHbLghCKroe57kazNLugS_UXtncgnDZ0NKir76bA2GrFQRBNm1QEB1-Jj38oIum1QKAtVjE02ZIfQNXtO-YxCrxr5LU_Uavhy3hmm6XDilJxhwO_97zk9WsehctWoWu5vs2h7okCa1Q&ts=1653947945114'+ocstr+'"; path=/'; return true;}
# function prjbottomclk(el,jobdata,oc) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1g4bflk4qq033801&from=reconserp&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvGRc6T1oNz2SAHbLghCKroe57kazNLugS_UXtncgnDZ0NKir76bA2GrFQRBNm1QEB1-Jj38oIum1QKAtVjE02ZIfQNXtO-YxCrxr5LU_Uavhy3hmm6XDilJxhwO_97zk9WsehctWoWu5vs2h7okCa1Q&ts=1653947945114'+ocstr+'"; path=/'; return true;}
# var jobmap = {};
#
# jobmap[0]= {jk:'8bdb0a9c1b4b6f33',efccid: '9828347d3ad610d0',srcid:'82c5f4b700425d1a',cmpid:'abe166c3bc950abc',num:'0',srcname:'Discord',cmp:'Discord',cmpesc:'Discord',cmplnk:'/q-Discord-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94107',country:'US',zip:'',city:'San Francisco',title:'Director of Engineering, Persistence',locid:'6cf5e6d389fd6d6b',rd:'0HcsNzDq-OLJ6bT4SC-8zCdqDNeXCouNMoTn7IvGRsJypdUSJby9ZG27QjyDkTXN'};
#
# jobmap[1]= {jk:'286fec0793307370',efccid: 'a18df02f3031a5a7',srcid:'563c59d68510b291',cmpid:'a411072d5a46f13f',num:'1',srcname:'City and County of San Francisco',cmp:'City and County of San Francisco',cmpesc:'City and County of San Francisco',cmplnk:'/q-City-and-County-of-San-Francisco-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94102',country:'US',zip:'94102',city:'San Francisco',title:'Journey Information Systems Engineer - Applications Specialty - City and County of San Francisco - Multiple Departments Citywide - 1042',locid:'6cf5e6d389fd6d6b',rd:'YwImFk4KXnuThxVBu4H4-oziA3zeRUrTd9YvprsGLzrYslb4OpDUEwZLufgK6KxT'};
#
# jobmap[2]= {jk:'b3ac8952187c7f38',efccid: 'd5cd619626c9f6f7',srcid:'1ad3dac1d3370c31',cmpid:'a5b4499d9e91a5c6',num:'2',srcname:'Google',cmp:'Google',cmpesc:'Google',cmplnk:'/q-Google-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA',country:'US',zip:'',city:'San Francisco',title:'Program Manager, Office of the Chief Technology Officer',locid:'6cf5e6d389fd6d6b',rd:'fmQo99wCEscDVgmVOMcwfFJM-sEmBVjfDD6ms_7DfEAs6Wa8eaVMIr0-ql1fmngV'};
#
# jobmap[3]= {jk:'b8a2315508208a9f',efccid: '4acb742f1f8f8d98',srcid:'ec694659f64ee919',cmpid:'fffaed0a03631bb6',num:'3',srcname:'Disney',cmp:'Lucasfilm',cmpesc:'Lucasfilm',cmplnk:'/q-Lucasfilm-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94129',country:'US',zip:'',city:'San Francisco',title:'Desktop Systems Specialist, Level I',locid:'6cf5e6d389fd6d6b',rd:'2xoO0TjyPVRYyCMAB-zZvQH-Mh7EjnwAv-42dWfx5bhypdUSJby9ZG27QjyDkTXN'};
#
# jobmap[4]= {jk:'0d2290656458e437',efccid: '9828347d3ad610d0',srcid:'82c5f4b700425d1a',cmpid:'abe166c3bc950abc',num:'4',srcname:'Discord',cmp:'Discord',cmpesc:'Discord',cmplnk:'/q-Discord-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94107',country:'US',zip:'',city:'San Francisco',title:'Product Manager, Growth',locid:'6cf5e6d389fd6d6b',rd:'M8curE_78AB2NZz5sTSH0onkMpcLeNJrZBALU94LbKz8BChA0uFybm70vS5pOUm-'};
#
# jobmap[5]= {jk:'df0232a2effb091d',efccid: '8aa898698d7a3b8e',srcid:'157205153497c646',cmpid:'22eaa529254aa908',num:'5',srcname:'Grammarly, Inc.',cmp:'Grammarly, Inc.',cmpesc:'Grammarly, Inc.',cmplnk:'/q-Grammarly-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94104',country:'US',zip:'',city:'San Francisco',title:'Manager, Information Technology (IT)',locid:'6cf5e6d389fd6d6b',rd:'L1jYwnlK9Pyu3RXUemdg7_RGU9Q1BsEfTiAwZyPAzqU9LGu2QN-byr6L3ccBoiH_'};
#
# jobmap[6]= {jk:'1a1a45797a9c9ed2',efccid: 'a18df02f3031a5a7',srcid:'563c59d68510b291',cmpid:'a411072d5a46f13f',num:'6',srcname:'City and County of San Francisco',cmp:'City and County of San Francisco',cmpesc:'City and County of San Francisco',cmplnk:'/q-City-and-County-of-San-Francisco-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94103',country:'US',zip:'94103',city:'San Francisco',title:'Desktop Support Specialist (1093) - Department of Technology',locid:'6cf5e6d389fd6d6b',rd:'PWfcGNFA7tgIDxGVBcVa2CA6mI6xhKRFdgVZF9Rf_QIBtdHSdrUpYKytXbN4mNaL'};
#
# jobmap[7]= {jk:'4ce542216e4493e3',efccid: 'a18df02f3031a5a7',srcid:'563c59d68510b291',cmpid:'a411072d5a46f13f',num:'7',srcname:'City and County of San Francisco',cmp:'City and County of San Francisco',cmpesc:'City and County of San Francisco',cmplnk:'/q-City-and-County-of-San-Francisco-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94103',country:'US',zip:'94103',city:'San Francisco',title:'IS Business Analyst \u2013 Information Technology - Human Services Agency (1052)',locid:'6cf5e6d389fd6d6b',rd:'hpDeP50szArAy57edipA-vJx7BugN8z3k4xG20EK6PjVhJ1WRKs2MqLg_ShYL2Da'};
#
# jobmap[8]= {jk:'c6a21c9367737e90',efccid: 'ec860fc66079875a',srcid:'f813117a1e1a48f8',cmpid:'04c6165cf2c77d28',num:'8',srcname:'JPMorgan Chase',cmp:'JPMorgan Chase Bank, N.A.',cmpesc:'JPMorgan Chase Bank, N.A.',cmplnk:'/q-JPMorgan-Chase-Bank,-N.A-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA',country:'US',zip:'',city:'San Francisco',title:'Investment Banking - Technology - Analyst',locid:'6cf5e6d389fd6d6b',rd:'Hn-YrsnGnu3NTWR3wHbwDpUdLuV_SDzKbpFo_M6QK1newWlzxlDbEKj7pBSGw0Hp'};
#
# jobmap[9]= {jk:'7a7d0fc7c11581d2',efccid: 'd22dcd666d39d744',srcid:'c1acecfd98e6c444',cmpid:'e0b68dd1a834ccf1',num:'9',srcname:'Indeed',cmp:'Dialog',cmpesc:'Dialog',cmplnk:'/q-Dialog-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA',country:'US',zip:'',city:'San Francisco',title:'Junior IT Specialist',locid:'6cf5e6d389fd6d6b',rd:'7QYyVeYoxkhWGKwlp23oXX8DoJ7Wu5sYj0AcxNs5UQYrvbYUKoeIK0Jpfa8XgTUt'};
#
# jobmap[10]= {jk:'529083e990483fa8',efccid: '9915d24c63d80679',srcid:'b86016c88bbeb38b',cmpid:'61df31dc91490d65',num:'10',srcname:'EBMUD',cmp:'EBMUD',cmpesc:'EBMUD',cmplnk:'/q-EBMUD-l-San-Francisco,-CA-jobs.html',loc:'Oakland, CA 94607',country:'US',zip:'94607',city:'Oakland',title:'Chief Information Officer',locid:'c9722299f228be48',rd:'KEojtcqEnWO4vKOgmVix-Ww2gXv0XBHqj99U3g2ddtuqFKgsltcx_ItNcd0pL7Ls'};
#
# jobmap[11]= {jk:'4648517a71e4f182',efccid: '8aa898698d7a3b8e',srcid:'157205153497c646',cmpid:'22eaa529254aa908',num:'11',srcname:'Grammarly, Inc.',cmp:'Grammarly, Inc.',cmpesc:'Grammarly, Inc.',cmplnk:'/q-Grammarly-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA 94104',country:'US',zip:'',city:'San Francisco',title:'Developer Educator',locid:'6cf5e6d389fd6d6b',rd:'mHicHdTSLcvPJb-Z8JIBkDv3k2jq4lDtqGKimPVwGX93aQQRoHSohP-6lkE-W2Oy'};
#
# jobmap[12]= {jk:'334710800248d3cb',efccid: 'e5e7673a9e0a11c5',srcid:'71b38631ef50cbc0',cmpid:'938c68fc89db4b9d',num:'12',srcname:'California State University',cmp:'California State University',cmpesc:'California State University',cmplnk:'/q-California-State-University-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA',country:'US',zip:'',city:'San Francisco',title:'Technology Support Analyst',locid:'6cf5e6d389fd6d6b',rd:'JoUIBMKxP_A2R-57uTJs0Y2OEkOwSw4DnIXJFT6lUD1gJEECe6Gbn3J7sWlDyr4l'};
#
# jobmap[13]= {jk:'950cd0b4e44bb59e',efccid: 'ba979d6fb0c7a936',srcid:'1c248d1533c507ca',cmpid:'a3f737e511d9fc8c',num:'13',srcname:'Visa',cmp:'Visa',cmpesc:'Visa',cmplnk:'/q-Visa-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA',country:'US',zip:'',city:'San Francisco',title:'Associate Product Manager - New College Grad (Undergraduate)',locid:'6cf5e6d389fd6d6b',rd:'qMjHLZIlDvgLWRb6iN1qjncc_JBvsRhSlc11-1IW98XYvst5HpYoh0FuVAogklko'};
#
# jobmap[14]= {jk:'c4a1b9ab34e319b4',efccid: '290d1b1651f39607',srcid:'bf9caa78976ea414',cmpid:'9474516a9efc22f2',num:'14',srcname:'Four Seasons',cmp:'Four Seasons',cmpesc:'Four Seasons',cmplnk:'/q-Four-Seasons-l-San-Francisco,-CA-jobs.html',loc:'San Francisco, CA',country:'US',zip:'',city:'San Francisco',title:'Senior Director of Information Technology',locid:'6cf5e6d389fd6d6b',rd:'CzXLwDvznu-4DEw90MS-45Cy0TcQ-at8r-4lt_ptucyVYOQdIRbUAO0X3Bjh9qOv'};
# </script>
# <style type="text/css">
# .jobtitle {
# font-weight: bold;
# }
# td.snip b, span.company b, #femp_list .jobtitle, #cmpinfo_list .jobtitle, .jobtitle .new, .unifiedRow .summary b {
# font-weight: normal;
# }
# div.result-link-bar b {
# font-weight: bold;
# }
# </style>
# <style type="text/css">
# div.row table tr td.snip, .unifiedRow .summary { line-height: 1.4; }
# </style>
# <table class="centered" id="resultsBody" role="presentation"><tbody id="resultsBodyContent"><tr><td>
# <script type="text/javascript">
#     window['ree'] = "pdsssps";
#     window['jas'] = "d3GnHKkCN";
# </script>
# <table class="serpContainerMinHeight" id="pageContent" role="presentation" style="padding: 0; border-spacing: 0; border: 0; width: 100%;">
# <tbody><tr role="main" style="vertical-align: top;">
# <td id="resultsCol">
# <div id="resultsColTopSpace"></div>
# <div class="messageContainer">
# <script type="text/javascript">
#       function setRefineByCookie(refineByTypes) {
#         var expires = new Date();
#         expires.setTime(expires.getTime() + (10 * 1000));
#         for (var i = 0; i < refineByTypes.length; i++) {
#           setCookie(refineByTypes[i], "1", expires);
#         }
#       }
#     </script>
# </div>
# <style type="text/css">
#     #increased_radius_result {
#         font-size: 1rem;
#         font-style: italic;
#     }
#     #original_radius_result{
#         font-size: 0.8125rem;
#         font-style: italic;
#         color: #666666;
#     }
# </style>
# <div class="resultsTop"><div class="mosaic-zone" id="mosaic-zone-aboveJobCards"><div class="mosaic mosaic-provider-serpreportjob mosaic-provider-hydrated" id="mosaic-provider-serpreportjob"><div aria-live="assertive" class="mosaic-reportcontent-wrapper"><div class="mosaic-reportcontent-content"></div></div></div></div><script type="text/javascript">
#                 try {
#                     window.mosaic.onMosaicApiReady(function() {
#                         var zoneId = 'aboveJobCards';
#                         var providers = window.mosaic.zonedProviders[zoneId];
#
#                         if (providers) {
#                             providers.filter(function(p) { return window.mosaic.lazyFns[p]; }).forEach(function(p) {
#                                 return window.mosaic.api.loadProvider(p);
#                             });
#                         }
#                     });
#                  } catch (e) {};
#                 </script><link href="//d3fw5vlhllyvee.cloudfront.net/s/b26123d/uploadedResumePromo.css" rel="stylesheet"/><div class="uploadedResumePromo hidden regBorderTop" id="uploadedResumePromo"><script type="text/javascript">if (null !== call_when_jsall_loaded) {call_when_jsall_loaded(function() {if(!!window.logPromoImpression &&  false ) {window.logPromoImpression('trk.origin=jobsearch&trk.variant=postApplySerpPromo&trk.tk=1g4bflk4qq033801', 'resume');}if(!!window.logPromoConditionMet) {window.logPromoConditionMet('trk.tk=1g4bflk4qq033801&ctk=1g4bflk2hr0is800&conditionMet=postApplySerpPromo', window['indeedCsrfToken']);}})}</script><div class="uploadedResumePromoPinkMask" id="uploadedResumePromoPinkMask"><div class="uploadedResumePromoCloseButton maskTop" id="uploadedResumePromoCloseButton" onclick="window.setCookie('hideUploadedResumePromo', '1'); window.deleteIACookies('.indeed.com'); document.getElementById('uploadedResumePromo').style.display = 'none'; window.logPromoClick('trk.origin=jobsearch&amp;trk.variant=postApplySerpPromo&amp;trk.tk=1g4bflk4qq033801', 'uploadedResumePromoCloseButton', '');"><button class="icl-CloseButton uploadedResumePromoCloseButton-close"><svg aria-label="Close" class="icl-Icon icl-Icon--sm icl-Icon--black close" focusable="false" role="img"><g><path d="M14.53,4.53L13.47,3.47,9,7.94,4.53,3.47,3.47,4.53,7.94,9,3.47,13.47l1.06,1.06L9,10.06l4.47,4.47,1.06-1.06L10.06,9Z"></path></g></svg></button></div></div><div class="uploadedResumePromoContentContainer" id="uploadedResumePromoContentContainer"><div class="uploadedResumePromoTitle titleUp">Forgot to save your resume?</div><div class="uploadedResumePromoText" id="uploadedResumePromoText">Use <span id="uploadedResumePromoFileName"></span> for <span id="uploadedResumePromoEmail"></span> to create your resume on Indeed and apply to jobs quicker.</div><div class="uploadedResumePromoCta"><style type="text/css">
#         .cta_button {
#             text-decoration:none !important;
#             margin: 12px !important;
#         }
#
#         .cta_button.blue  {
#             color: #f8f8f9 !important;
#         }
#
#         .cta_button.grey {
#             color: #000000 !important;
#         }
#
#         .cta_button.uploaded {
#             border-radius: 100px !important;
#             font-size: 0.75rem;
#             line-height: 1rem;
#             text-align: center;
#             padding: 8px;
#         }
#
#         .cta_button.continue {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #195ff7 !important;
#             width: 163px;
#         }
#
#         .cta_button.accept {
#             color: #ffffff !important;
#             background-color: #085ff7 !important;
#             border: 2px solid #085ff7 !important;
#             width: 106px;
#             display: inline-block;
#         }
#
#         .cta_button.back {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #cccccc !important;
#             width: 106px;
#             margin-left: -4px !important;
#         }
#         </style><span dir="ltr"><a class="icl-Button icl-Button--secondary icl-Button--sm cta_button uploaded continue" onclick="document.getElementById('uploadedResumePromoCloseButton').style.display = 'none'; if (document.getElementById('uploadedResumePromoPinkMask')) {document.getElementById('uploadedResumePromoPinkMask').style.height = '50px';}document.getElementById('uploadedResumePromoContentContainer').style.display = 'none'; document.getElementById('uploadedResumePromoPolicyContainer').style.display = 'block'; window.logPromoClick('trk.origin=jobsearch&amp;trk.variant=postApplySerpPromo&amp;trk.tk=1g4bflk4qq033801&amp;trk.pos=postApplySerpPromoClick', 'resume','');">Save your resume</a></span></div></div><div class="uploadedResumePromoPolicyContainer" id="uploadedResumePromoPolicyContainer"><div class="uploadedResumePromoPolicy">By creating an Indeed Resume, you agree to Indeed's <a class="uploadedResumePolicyHighlight" href="/legal#tos">Terms of Service</a>, <a class="uploadedResumePolicyHighlight" href="/legal#cookies">Cookie Policy</a> and <a class="uploadedResumePolicyHighlight" href="/legal#privacy">Privacy Policy</a>, and agree to be contacted by employers via Indeed. You consent to receiving marketing messages from Indeed and may opt from receiving such messages by following the unsubscribe link in our messages, or as detailed in our terms.</div><div class="uploadedResumePromoConfirmCta"><style type="text/css">
#         .cta_button {
#             text-decoration:none !important;
#             margin: 12px !important;
#         }
#
#         .cta_button.blue  {
#             color: #f8f8f9 !important;
#         }
#
#         .cta_button.grey {
#             color: #000000 !important;
#         }
#
#         .cta_button.uploaded {
#             border-radius: 100px !important;
#             font-size: 0.75rem;
#             line-height: 1rem;
#             text-align: center;
#             padding: 8px;
#         }
#
#         .cta_button.continue {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #195ff7 !important;
#             width: 163px;
#         }
#
#         .cta_button.accept {
#             color: #ffffff !important;
#             background-color: #085ff7 !important;
#             border: 2px solid #085ff7 !important;
#             width: 106px;
#             display: inline-block;
#         }
#
#         .cta_button.back {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #cccccc !important;
#             width: 106px;
#             margin-left: -4px !important;
#         }
#         </style><span dir="ltr"><form action="/account/myindregister" class="uploadedResumePromoForm" id="uploadedResumePromoForm" method="POST" novalidate=""><input name="from" type="hidden" value="inlineResumeCta"/><input class="icl-Button icl-Button--secondary icl-Button--sm cta_button uploaded accept" onclick="window.setCookie('hideUploadedResumePromo', '1'); window.logPromoClick('trk.origin=jobsearch&amp;trk.variant=postApplySerpPromo&amp;trk.tk=1g4bflk4qq033801&amp;trk.pos=postApplyPromoDisclaimerClick', 'resume','/promo/resume?from=inlineUploadedCta&amp;trk.origin=inlineUploadedCta');" type="submit" value="Accept"/></form></span><style type="text/css">
#         .cta_button {
#             text-decoration:none !important;
#             margin: 12px !important;
#         }
#
#         .cta_button.blue  {
#             color: #f8f8f9 !important;
#         }
#
#         .cta_button.grey {
#             color: #000000 !important;
#         }
#
#         .cta_button.uploaded {
#             border-radius: 100px !important;
#             font-size: 0.75rem;
#             line-height: 1rem;
#             text-align: center;
#             padding: 8px;
#         }
#
#         .cta_button.continue {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #195ff7 !important;
#             width: 163px;
#         }
#
#         .cta_button.accept {
#             color: #ffffff !important;
#             background-color: #085ff7 !important;
#             border: 2px solid #085ff7 !important;
#             width: 106px;
#             display: inline-block;
#         }
#
#         .cta_button.back {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #cccccc !important;
#             width: 106px;
#             margin-left: -4px !important;
#         }
#         </style><span dir="ltr"><a class="icl-Button icl-Button--secondary icl-Button--sm cta_button uploaded back" onclick="document.getElementById('uploadedResumePromoCloseButton').style.display = 'block'; if (document.getElementById('uploadedResumePromoPinkMask')) {document.getElementById('uploadedResumePromoPinkMask').style.height = '81px';}document.getElementById('uploadedResumePromoContentContainer').style.display = 'block'; document.getElementById('uploadedResumePromoPolicyContainer').style.display = 'none'; window.logPromoClick('trk.origin=jobsearch&amp;trk.variant=postApplySerpPromo&amp;trk.tk=1g4bflk4qq033801', 'resume','');">Back</a></span></div></div></div><div data-tn-section="resumePromo" id="resumePromo">
# <a aria-hidden="true" href="/promo/resume" onclick="this.href = appendParamsOnce( this.href, '?from=serptop3&amp;subfrom=resprmrtop&amp;trk.origin=jobsearch&amp;trk.variant=resprmrtop&amp;trk.tk=1g4bflk4qq033801')" tabindex="-1"><span class="new-ico" role="img"></span></a> <a class="resume-promo-link" href="/promo/resume" onclick="this.href = appendParamsOnce( this.href, '?from=serptop3&amp;subfrom=resprmrtop&amp;trk.origin=jobsearch&amp;trk.variant=resprmrtop&amp;trk.tk=1g4bflk4qq033801')"><b>Upload your resume</b></a> - Let employers find you</div><h1 class="currentSearchLabel-a11y-contrast-color" id="jobsInLocation" style="">
#         information technology jobs in San Francisco, CA</h1><div class="secondRow">
# <div class="serp-filters-sort-by-container">
# <span class="serp-filters-sort-by-label">Sort by: </span>
# <span class="no-wrap"><b>relevance</b> -
# <a href="/jobs?q=information+technology&amp;l=San+Francisco%2C+CA&amp;sort=date" rel="nofollow">date</a></span>
# </div><div class="searchCountContainer">
# <div class="searchCount-a11y-contrast-color" id="searchCount">
# <div id="searchCountPages">
#                     Page 1 of 8,837 jobs</div>
# <div class="serp-relevance-explanation"><button aria-haspopup="true" aria-label="help" class="serp-relevance-explanation-helpIcon serp-helpIcon" type="button"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><lineargradient id="helpIcon-a" x1="50%" x2="50%" y1="0%" y2="100%"><stop offset="0%" stop-color="#FFF" stop-opacity=".5"></stop><stop offset="100%" stop-opacity=".5"></stop></lineargradient><lineargradient id="helpIcon-b" x1="50%" x2="50%" y1="0%" y2="100%"><stop offset="0%" stop-opacity=".5"></stop><stop offset="100%" stop-opacity=".5"></stop></lineargradient><path d="M7.1537 3.391C8.373 3.4665 9.3466 4.44 9.4223 5.6594 9.4886 6.7088 8.8736 7.6823 7.9 8.0702c-.1413.0563-.2358.1796-.2358.321v.6619h-1.324v-.662c0-.6894.4162-1.2944 1.0687-1.5497.4442-.1795.7283-.6244.6995-1.0968-.0382-.548-.4824-.9922-1.0304-1.0304-.3116-.0282-.605.085-.8315.2934-.2271.2077-.3504.4911-.3504.8034v.662H4.5728v-.662c0-.662.2834-1.3146.7658-1.7682.4911-.463 1.1343-.6995 1.815-.6519zM6.33 10.22c0-.368.2586-.6649.6606-.6683.004 0 .0047-.002.006-.002h.0114v.004c.412.0157.662.3064.662.6656-.0087.3736-.2566.6595-.662.667-.0013.0034-.0033.002-.0053.002-.0034 0-.006.0014-.008.0014-.0027 0-.0027-.0014-.004-.0014-.4-.0142-.6607-.2981-.6607-.6683zM1.6407 7c0-2.9554 2.4046-5.36 5.36-5.36 2.9553 0 5.36 2.4046 5.36 5.36 0 2.9554-2.4047 5.36-5.36 5.36-2.9554 0-5.36-2.4046-5.36-5.36zM.3 7c0 3.6997 3.0003 6.7 6.7 6.7 3.7004 0 6.7-3.0003 6.7-6.7C13.7 3.2996 10.7004.3 7 .3 3.3003.3.3 3.2996.3 7z" id="helpIcon-c"></path></defs><g fill="none" fill-rule="evenodd"><g fill-rule="nonzero"><path d="M8.1537 4.391c1.2194.0756 2.1929 1.0491 2.2686 2.2685.0663 1.0493-.5487 2.0228-1.5223 2.4107-.1413.0563-.2358.1796-.2358.321v.6619h-1.324v-.662c0-.6894.4162-1.2944 1.0687-1.5497.4442-.1795.7283-.6244.6995-1.0968-.0382-.548-.4824-.9922-1.0304-1.0304-.3116-.0282-.605.085-.8315.2934-.2271.2077-.3504.4911-.3504.8034v.662H5.5728v-.662c0-.662.2834-1.3146.7658-1.7682.4911-.463 1.1343-.6995 1.815-.6519zM7.33 11.22c0-.368.2586-.6649.6606-.6683.004 0 .0047-.002.006-.002h.0114v.004c.412.0157.662.3064.662.6656-.0087.3736-.2566.6595-.662.667-.0013.0034-.0033.002-.0053.002-.0034 0-.006.0014-.008.0014-.0027 0-.0027-.0014-.004-.0014-.4-.0142-.6607-.2981-.6607-.6683zM2.6407 8c0-2.9554 2.4046-5.36 5.36-5.36 2.9553 0 5.36 2.4046 5.36 5.36 0 2.9554-2.4047 5.36-5.36 5.36-2.9554 0-5.36-2.4046-5.36-5.36zM1.3 8c0 3.6997 3.0003 6.7 6.7 6.7 3.7004 0 6.7-3.0003 6.7-6.7 0-3.7004-2.9996-6.7-6.7-6.7-3.6997 0-6.7 2.9996-6.7 6.7z" fill="#D8D8D8"></path><path d="M7.1537 3.391C8.373 3.4665 9.3466 4.44 9.4223 5.6594 9.4886 6.7088 8.8736 7.6823 7.9 8.0702c-.1413.0563-.2358.1796-.2358.321v.6619h-1.324v-.662c0-.6894.4162-1.2944 1.0687-1.5497.4442-.1795.7283-.6244.6995-1.0968-.0382-.548-.4824-.9922-1.0304-1.0304-.3116-.0282-.605.085-.8315.2934-.2271.2077-.3504.4911-.3504.8034v.662H4.5728v-.662c0-.662.2834-1.3146.7658-1.7682.4911-.463 1.1343-.6995 1.815-.6519zM6.33 10.22c0-.368.2586-.6649.6606-.6683.004 0 .0047-.002.006-.002h.0114v.004c.412.0157.662.3064.662.6656-.0087.3736-.2566.6595-.662.667-.0013.0034-.0033.002-.0053.002-.0034 0-.006.0014-.008.0014-.0027 0-.0027-.0014-.004-.0014-.4-.0142-.6607-.2981-.6607-.6683zM1.6407 7c0-2.9554 2.4046-5.36 5.36-5.36 2.9553 0 5.36 2.4046 5.36 5.36 0 2.9554-2.4047 5.36-5.36 5.36-2.9554 0-5.36-2.4046-5.36-5.36zM.3 7c0 3.6997 3.0003 6.7 6.7 6.7 3.7004 0 6.7-3.0003 6.7-6.7C13.7 3.2996 10.7004.3 7 .3 3.3003.3.3 3.2996.3 7z" fill="url(#helpIcon-a)" transform="translate(1 1)"></path><path d="M7.1537 3.391C8.373 3.4665 9.3466 4.44 9.4223 5.6594 9.4886 6.7088 8.8736 7.6823 7.9 8.0702c-.1413.0563-.2358.1796-.2358.321v.6619h-1.324v-.662c0-.6894.4162-1.2944 1.0687-1.5497.4442-.1795.7283-.6244.6995-1.0968-.0382-.548-.4824-.9922-1.0304-1.0304-.3116-.0282-.605.085-.8315.2934-.2271.2077-.3504.4911-.3504.8034v.662H4.5728v-.662c0-.662.2834-1.3146.7658-1.7682.4911-.463 1.1343-.6995 1.815-.6519zM6.33 10.22c0-.368.2586-.6649.6606-.6683 ...
# </div></div>
# </div>
# <a id="jobPostingsAnchor" tabindex="-1"></a>
# <script type="text/javascript">
#             window['onJobCardItemMouseDown'] = function(event, data) {
#                 if(data['sponsored']) {
#                     sjomd(data['id']); clk(data['id']); rclk(this, data['jobdata'], false, data['hasSalary'] ? '1' : '0');
#                 } else {
#                     rclk(this, data['jobdata'], false, data['hasSalary'] ? '1' : '0');
#                 }
#             };
#             window['onJobCardItemClick'] = function(event, data) {
#                 if(data['sponsored']) {
#                     setRefineByCookie(data['refineByTypes']); sjoc(data['id'], data['hasSalary'] ? '1' : '0'); convCtr('SJ'); rclk(this, data['jobdata'], true, data['hasSalary'] ? '1' : '0');
#                 } else {
#                     setRefineByCookie(data['refineByTypes']); rclk(this, data['jobdata'], true, data['hasSalary'] ? '1' : '0');
#                 }
#                 if (window['2paneEnabled']) {
#                     var twoPaneRendered = viewJobOnSerp.onJCSMouseDown2pane(event, data['option'], data['id']);
#                     if (twoPaneRendered) {
#                         event.preventDefault(); // prevent the default behavior of clicking <a> on JCS
#                     }
#                     if (data['setFocusToJobDetails']) {
#                         var focusTarget = document.querySelector('#vjs-container');
#                         if (focusTarget) {
#                             focusTarget.focus();
#                         }
#                     }
#                 }
#             }
#             window['handleAdditionalLocationLinkMouseDown'] = function(event, data) {
#                 ptk('addlloc');
#             }
#             window['handleDislikeClick'] = function(data) {
#                 // attempt to close 2pane
#                 window['dislikedJobKey'] = data.jobKey;
#                 window.dispatchEvent(new Event('dislikeJob'));
#             }
#         </script>
# ...
# this['i18n.MosaicProviderRichSearchDaemon']={"":{"Content-Type":" text/plain; charset=UTF-8","Locale":"en_US","Plural-Forms":" nplurals=2; plural=n != 1;"},"'Apply from your phone' jobs":[null,""],"Add location":[null,""],"Advanced Job Search":[null,"Advanced Job Search"],"All Job Types":[null,""],"All filter options secondary dialog":[null,""],"All filters":[null,"All filters"],"App Header\u0004home":[null,""],"Apply filter selection\u0004Update":[null,""],"Aria Label for where autocomplete suggestion\u0004Search suggestions":[null,""],"Aria label for web dialog and cancel button\u0004Cancel button for edit the location web dialog":[null,""],"Back":[null,""],"Browse categories":[null,""],"Cancel":[null,""],"Clear":[null,""],"Clear Multi-Select filter selections\u0004Clear all":[null,""],"Clear Single-Select filter selection\u0004Reset":[null,""],"Clear all":[null,""],"Clear {0} filter":[null,""],"Close":[null,""],"Close filter selection overlay\u0004Cancel":[null,""],"Close where search overlay\u0004Cancel":[null,""],"Current Location":[null,""],"Current location\u0004Current Location":[null,""],"Custom Location\u0004Close":[null,""],"Custom location\u0004City, state, zip code or \"remote\"":[null,""],"Custom location\u0004Search by name or zip code":[null,""],"Dialog for changing filter selection\u0004Edit {0} filter selection":[null,""],"Dialog for changing what\u0004Search":[null,""],"Dialog for changing where\u0004Location":[null,""],"Dialog for changing where in Search area Overlay\u0004Edit your search location":[null,""],"Distance":[null,""],"Edit":[null,""],"Edit location input box label\u0004Edit location":[null,""],"Edit search input box label\u0004Edit search":[null,""],"Edit search input box label\u0004Edit search: Job title or keywords at {0}":[null,""],"Edit search radius":[null,""],"Edit your search location\u0004Edit your search location":[null,""],"Error Icon label\u0004Error":[null,""],"Exact location":[null,""],"Filter pill button to describe search radius\u0004within {0} mile":["within {0} miles","",""],"Filter {0} has been removed":[null,""],"Filters":[null,""],"Find Jobs button\u0004Find Jobs":[null,""],"Find jobs":[null,""],"Generic title for when when current location retrieval fails\u0004Error getting current location":[null,""],"Industries":[null,""],"Industry":[null,""],"Japan rich serp\u0004Clear all conditions":[null,""],"Japan rich serp\u0004No search criteria":[null,""],"Japan rich serp\u0004Please set work location and desired conditions":[null,""],"Japan rich serp\u0004Please set work location and keywords":[null,""],"Japan rich serp\u0004Search is not successful":[null,""],"Job Type":[null,""],"Job type":[null,""],"Job types":[null,""],"Location":[null,""],"Location is required":[null,""],"Locations":[null,""],"Need more search ideas?":[null,""],"New":[null,""],"New job count indicator\u0004<span class=\"yosegi-RecentSearchList-newJobs\">{0} new</span> in {1}":[null,""],"New jobs":[null,""],"No":[null,""],"Opt out company SERP mode menu item\u0004Search jobs at all companies":[null,""],"Query replace\u0004Did you mean: <a className=\"yosegi-QueryReplace-link\" href={0}>{1}</a>":[null,""],"Query replace\u0004Showing results for <b>{0}</b> jobs":[null,""],"Remote Search Callout\u0004Close":[null,""],"Remote Search Callout Message\u0004Showing all {0} jobs in the US. Do you want to see {0} jobs in {1} only?":[null,""],"Remove {0}":[null,""],"Reset":[null,""],"Rich Serp filter pane\u0004Jobs that can be applied within Indeed":[null,""],"Rich Serp filter pane\u0004Only show easy apply jobs":[null,""],"Salary":[null,""],"Search box edit location label for opening dialog\u0004Edit location: {0}":[null,""],"Search box edit location label for opening dialog with radius\u0004Edit search area: {0}":[null,""],"Search box edit query label for opening dialog\u0004Edit search: {0}":[null,""],"Search box location placeholder\u0004City, state, zip code, or \"remote\"":[null,""],"Search box query placeholder\u ...
# </script>
# <script>window['sendPageLoadEndPing'] = function(pageId, tk, st) {var validPageIds = ['viewjob', 'serp']; if (!!Image && validPageIds.indexOf(pageId) > -1 && !!tk && !!st) {var href = '/rpc/pageLoadEnd?pageId=' + pageId + '&tk=' + tk + '&st=' + st + '&__=' + Math.random(); var img = new Image(); img.src = href;}}; window['sendPageLoadEndPing']("serp", "1g4bflk4qq033801", "1653947945114");</script><div class="mosaic-zone" id="mosaic-zone-serpBottomBody"><div class="mosaic mosaic-provider-signinprompt mosaic-rst mosaic-provider-hydrated" id="mosaic-provider-signinprompt"></div><div class="mosaic mosaic-provider-dislike-feedback mosaic-provider-hydrated" id="mosaic-provider-dislike-feedback"><div class="animatedToast i-unmask"><div class=""></div></div></div></div><script type="text/javascript">
#                 try {
#                     window.mosaic.onMosaicApiReady(function() {
#                         var zoneId = 'serpBottomBody';
#                         var providers = window.mosaic.zonedProviders[zoneId];
#
#                         if (providers) {
#                             providers.filter(function(p) { return window.mosaic.lazyFns[p]; }).forEach(function(p) {
#                                 return window.mosaic.api.loadProvider(p);
#                             });
#                         }
#                     });
#                  } catch (e) {};
#                 </script>
# <script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/0c0d4897e2393bbe87b2/scripts/index.js?cacheKey=1&amp;1"></script><link as="script" crossorigin="anonymous" href="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/header/remoteEntry.555b461c01a09cdf8c9f.js" rel="preload"/><link as="script" crossorigin="anonymous" href="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/inline/mainHeader.cc480cc48f2e38a69eff.js" rel="preload"/><link as="script" crossorigin="anonymous" href="https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?2" rel="preload"/><link as="script" crossorigin="anonymous" href="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/footer/remoteEntry.75b736ec0375878e8e48.js" rel="preload"/><link as="script" crossorigin="anonymous" href="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/inline/mainFooter.7ea1585565402778274d.js" rel="preload"/><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/inline/mainHeader.cc480cc48f2e38a69eff.js"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?2"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/inline/mainFooter.7ea1585565402778274d.js"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-salary-feedback/dist/i18n/35a3a4bc52e5ca7bba90/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-salary-feedback/dist/89ed0e6a2822dbdc3ce7/js/FeedbackSurvey-client.js?1"></script><script async="" crossorigin="anonymous" src="https://c03.s3.indeed.com/mosaic-provider-jobcards/dist/i18n/c268a763fe9c19b9c8e4/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://c03.s3.indeed.com/mosaic-provider-jobcards/dist/42f51707ad8ba74b3a9b/js/Main-client.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/i18n/e0eadcda5e0642254325/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/bdff8b33b06777738cda/js/SerpReportJob-client.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-rich-search/static/i18n/aacb2ac5406587d3d54e/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-rich-search/static/cc7fb54a22be8a1dc472/js/RichSearch.global-client.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-acme-content-collection/dist/i18n/f0f3ee101f21e1d90c5e/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-acme-content-collection/dist/c9f0fb4203f909e5b529/js/FeedbackSurvey-client.js?1"></script><script async="" crossorigin="anonymous" src="https://c03.s3.indeed.com/mosaic-provider-signinprompt/dist/i18n/f43d3227b299124bf8c7/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://c03.s3.indeed.com/mosaic-provider-signinprompt/dist/3a759a033f720cb90ec4/js/SignInPrompt-client.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobsearch-feedback/dist/i18n/6b666899cd446e2e389d/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobsearch-feedback/dist/da571c49a036a9096a81/js/DislikeFeedback-client.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/header/remoteEntry.555b461c01a09cdf8c9f.js"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/dist/ifl4/footer/r ...
# if (!window.ga) {
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#     ga('create','UA-90780-1','auto',{allowLinker:true});
#     ga('set', 'transport', 'beacon');
#     ga('require','linkid');
#     ga('require','linker');
#     ga('linker:autoLink', [
#         'indeed.co.in',
#         'indeed.lu',
#         'indeed.fr',
#         'indeed.de',
#         'indeed.com.br',
#         'indeed.co.uk',
#         'indeed.hk',
#         'indeed.fi',
#         'indeed.pt',
#         'indeed.jp',
#         'indeed.com',
#         'indeed.com.sg',
#         'indeed.nl',
#         'indeed.com.pk',
#         'indeed.cl',
#         'indeed.es',
#         'indeed.co.ve',
#         'indeed.ae',
#         'indeed.com.mx',
#         'indeed.com.my',
#         'indeed.ch',
#         'indeed.com.co',
#         'indeed.com.ph',
#         'indeed.co.za',
#         'indeed.ie',
#         'indeed.com.au',
#         'indeed.ca',
#         'indeed.com.pe'
#     ]);
#
#     ga('require','displayfeatures');
#     ga('send','pageview');
# }
# </script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-segmentation-serp-promo/dist/i18n/a1b0ef42fd003ac47d43/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-segmentation-serp-promo/dist/2b79ae2c78228cea7b5f/js/SerpPromo-client.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/uip-micro-content-provider/dist/i18n/1182c63556e3f2d2de10/en_US.js?1"></script><script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/uip-micro-content-provider/dist/c1abb7eb563061be510f/js/client-render.js?1"></script><script src="https://accounts.google.com/gsi/client"></script><img alt=" " aria-hidden="true" height="1" src="https://t.indeed.com/jsuip/log?moduleName=event&amp;logType=trackEvent&amp;ts=1028720.1000000238&amp;application=uip-common&amp;data%5BeventName%5D=mosaicContainerClick&amp;data%5BlogType%5D=mosaicUserInteraction&amp;data%5Bprovider%5D=mosaic-provider-jobcards&amp;data%5BparentLogId%5D=1g4bflkd9q033800&amp;data%5BhasHeight%5D=true&amp;data%5BhasHtml%5D=true&amp;data%5Bwidth%5D=410&amp;data%5Bheight%5D=4787&amp;data%5BclickTargetId%5D=job_8bdb0a9c1b4b6f33&amp;data%5BclickTargetTag%5D=A&amp;data%5BclickTargetClass%5D=jcs-JobTitle&amp;data%5BclickTargetParentId%5D=&amp;data%5BclickTargetParentTag%5D=H2&amp;data%5BclickTargetParentClass%5D=jobTitle%20jobTitle-color-purple&amp;type=mosaicUserInteraction&amp;parentLogId=1g4bflkd9q033800&amp;logTk=1g4bflk4qq033801&amp;platform=jasx&amp;pageId=serp&amp;ctk=1g4bflk2hr0is800&amp;country=US&amp;lth=3d8d54584153dd9f2adb9523b9d6135e" style="display: none;" width="1"/></body>

# %%
postings = soup.find_all("div", {"class": "jobsearch-jobDescriptionText"})

# %%
postings
# Out:
# []

# %%
res = requests.get(r"https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&sc=0kf%3Aexplvl(MID_LEVEL)jt(fulltime)%3B&vjk=2d96653fd7ce7276&advn=8134151690508319");

# %%
s1 = "https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&sc=0kf%3Aexplvl(MID_LEVEL)jt(fulltime)%3B&vjk=decd09bef6817b59"
s2 = "https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&sc=0kf%3Aexplvl(MID_LEVEL)jt(fulltime)%3B&start=10&vjk=6f73f30ce348025e"
s3 = "https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&sc=0kf%3Aexplvl(MID_LEVEL)jt(fulltime)%3B&start=20&vjk=44f7f98073d30cd6"
s4 = "https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&sc=0kf%3Aexplvl(MID_LEVEL)jt(fulltime)%3B&start=30&vjk=11b032d61c28b2cd"

# %%
for i in range(143):
    if(s1[i] != s2[i]):
        print(i)
# Out:
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 140
# 141
# 142

# %%
len(s2)
# Out:
# 143

# %%
def unicodetoascii(text):

    TEXT = (text.
    		replace('\\xe2\\x80\\x99', "'").
            replace('\\xc3\\xa9', 'e').
            replace('\\xe2\\x80\\x90', '-').
            replace('\\xe2\\x80\\x91', '-').
            replace('\\xe2\\x80\\x92', '-').
            replace('\\xe2\\x80\\x93', '-').
            replace('\\xe2\\x80\\x94', '-').
            replace('\\xe2\\x80\\x94', '-').
            replace('\\xe2\\x80\\x98', "'").
            replace('\\xe2\\x80\\x9b', "'").
            replace('\\xe2\\x80\\x9c', '"').
            replace('\\xe2\\x80\\x9c', '"').
            replace('\\xe2\\x80\\x9d', '"').
            replace('\\xe2\\x80\\x9e', '"').
            replace('\\xe2\\x80\\x9f', '"').
            replace('\\xe2\\x80\\xa6', '...').#
            replace('\\xe2\\x80\\xb2', "'").
            replace('\\xe2\\x80\\xb3', "'").
            replace('\\xe2\\x80\\xb4', "'").
            replace('\\xe2\\x80\\xb5', "'").
            replace('\\xe2\\x80\\xb6', "'").
            replace('\\xe2\\x80\\xb7', "'").
            replace('\\xe2\\x81\\xba', "+").
            replace('\\xe2\\x81\\xbb', "-").
            replace('\\xe2\\x81\\xbc', "=").
            replace('\\xe2\\x81\\xbd', "(").
            replace('\\xe2\\x81\\xbe', ")")

                 )
    return TEXT

# %%
res = requests.get(r"https://www.indeed.com/jobs?q=information%20technology&l=San%20Francisco%2C%20CA&sc=0kf%3Aexplvl(MID_LEVEL)jt(fulltime)%3B&vjk=2d96653fd7ce7276&advn=8134151690508319");

# %%
soup = BeautifulSoup(str(res.content), "html.parser")

# %%
elements = soup.find_all("a", {"class": "jcs-JobTitle"})

# %%
added_str = elements[0]["href"]
send_str = "https://www.indeed.com" + added_str
current_res = requests.get(send_str)

# %%
final_data = []

# %%
for n in range(10):
    res = requests.get(f"https://www.indeed.com//jobs?q=information+technology&l=San+Francisco%2C+CA&sc=0kf%3Aexplvl%28MID_LEVEL%29jt%28fulltime%29%3B&start={10*n}");
    soup = BeautifulSoup(str(res.content), "html.parser")
    elements = soup.find_all("a", {"class": "jcs-JobTitle"})

    for element in elements:
        added_str = element["href"]
        send_str = "https://www.indeed.com" + added_str
        current_res = requests.get(send_str)

        soup = BeautifulSoup(str(current_res.content), "html.parser")
        description = soup.find_all("div", {"class": "jobsearch-jobDescriptionText"})
        raw_text = str(description[0].text)
        raw_text = raw_text.replace("\\n","")
        raw_text = raw_text.replace("  "," ")
        final_data.append(raw_text)

# %%
final_data
# Out:
# [' Position Summary and Responsibilities: Field Service Technicians are responsible for responding to on-site requests for clients that cannot be resolved remotely. They create cases in the ConnectWise ticketing system, troubleshoot and resolve issues onsite, and when necessary, escalate cases to the appropriate senior technician or network administrator. FSTs have a strong technical background and an ability to listen and communicate effectively with clients and team members alike. While the FSTs work independently for the most part, they have the support of OneClicks\\xe2\\x80\\x99s internal team when onsite for assistance when needed. When there is no on-site work, the FST works internally and proactively helping to close other tickets remotely wherever possible. What do our Field Service Technicians do?  Travel to client sites a few days a week, providing technical support and guidance to end users, including diagnosing end-user issues, network, server, and workstation problems. Handle high impact client request, performing ad-hoc, independent troubleshooting in high-pressure situations. Keep clients informed of incident progress, notifying them of impending changes or agreed outages. Occasionally provide remote assistance for Network Administrators for some project/issue. deployment needs. This will require working closely with internal teammates and the ability to follow verbal and written instructions closely. Remain flexible and adaptable with scheduling, as priorities may change during a shift. Other relevant job duties as assigned. What skills do I need to be a successful Field Service Technician?  Patience, empathy, confidence, and customer service skills. You will be working with a myriad of businesses, technologies, applications, and personalities, in person. Exceptionally strong IT background with a focus on desktop support, implementation, and onsite as well as remote support. Experience with administering current Windows desktop operating systems, Exchange, Office 365, and a variety of backup solutions, anti-virus malware removal, and basic knowledge of virtual/cloud-based technologies. Ability to work effectively within a team as well as independently. Understanding of managed services and the value offered over a typical break-fix environment. Excellent communication (verbal and written) at all levels internally and externally, interpersonal business management, time management and developmental skills. Skilled at defusing high-stress situations and facilitating resolution to technical problems. Willingness to learn, adjust, and grow with our company. Ability to multi-task in a fast-paced environment. Professional appearance and attitude when interacting with clients in-person. Self-starter with a positive attitude. What are the qualifications I need to have?  High school diploma or equivalent. 3+ years of relevant experience which may include Help Desk Technician, Help Desk Analyst, or Tier 2 (or similar) in a tiered environment. Valid drive\\xe2\\x80\\x99s license with access to own vehicle. Excellent troubleshooting skills with IT and related hardware and software components (PCs, laptops, servers, firewalls, switches, routers, hard drives, Windows operating systems, etc.). Knowledge and experience working with Microsoft Office 365, Microsoft Azure and other Cloud service offerings. Previous experience providing both onsite and remote/phone support in a fast paced, high volume environment. Would be awesome if you have\\xe2\\x80\\xa6  Associate\\xe2\\x80\\x99s degree or higher in Information Technology. Understanding of, and a background in working within the IT managed services provider business model, particularly in an IT support role. Experience with ConnectWise, Continuum, or other similar MSP tools and software. Apple OSX and iOS experience. What is the physical work environment like?  This position requires onsite visits at our clients about 50% of the time The rest of the time will be working from h ...
#  "  Note: Google\\xe2\\x80\\x99s hybrid workplace includes remote and in-office roles. By applying to this position you will have an opportunity to share your preferred working location from the following:    In-office locations: San Francisco, CA, USA.   Remote location(s): California, USA; Oregon, USA; Washington, USA.  Minimum qualifications:    Bachelor\\'s degree in Computer Science, similar technical degree, or equivalent practical experience  Experience in program or project management   Preferred qualifications:    Experience navigating ambiguity  Demonstrated ability to drive projects, using project plans and other program management tools  Ability to balance multiple projects with different stakeholders simultaneously  Ability to collaborate across teams  Ability to use creativity or innovative thinking for impactful programs  Excellent verbal and written communication skills    About the job  A problem isn\\xe2\\x80\\x99t truly solved until it\\xe2\\x80\\x99s solved for all. That\\xe2\\x80\\x99s why Googlers build products that help create opportunities for everyone, whether down the street or across the globe. As a Program Manager at Google, you\\xe2\\x80\\x99ll lead complex, multi-disciplinary projects from start to finish \\xe2\\x80\\x94 working with stakeholders to plan requirements, manage project schedules, identify risks, and communicate clearly with cross-functional partners across the company. Your projects will often span offices, time zones, and hemispheres. It\\'s your job to coordinate the players and keep them up to date on progress and deadlines.   Our goal is to build a Google that looks like the world around us \\xe2\\x80\\x94 and we want Googlers to stay and grow when they join us. As part of our efforts to build a Google for everyone, we build diversity, equity, and inclusion into our work and we aim to cultivate a sense of belonging throughout the company.   The Office of the Chief Technology Officer (OCTO) is a diverse team of highly experienced Engineers and Technologists, working on behalf of the Google Cloud CEO, whose mission is to foster market-disrupting collaborative innovation between Google and the world\\'s most ambitious organizations. The customers we engage have hard technical problems and strong brand identities. As a Program Manager in OCTO, you will focus on team operations. This includes supporting OCTO foundationally run the business work and Applied Innovation Factory programs.  Google is an engineering company at heart. We hire people with a broad set of technical skills who are ready to take on some of technology\\'s greatest challenges and make an impact on users around the world. At Google, engineers not only revolutionize search, they routinely work on scalability and storage solutions, large-scale applications and entirely new platforms for developers around the world. From Google Ads to Chrome, Android to YouTube, social to local, Google engineers are changing the world one technological achievement after another.    Responsibilities    Leading a portfolio of strategic projects geared toward team operations.   Lead end-to-end program management of multiple, complex global programs and own communication to participants, managers, and executive leadership.   Manage stakeholders by following a technical conversation, summarizing, and presenting findings.   Build narratives that report program impact to stakeholders.   Help drive and define a new set of functions in OCTO as a program manager, helping to design and simplify processes, magnifying team impact.   Google is proud to be an equal opportunity workplace and is an affirmative action employer. We are committed to equal employment opportunity regardless of race, color, ancestry, religion, sex, national origin, sexual orientation, age, citizenship, marital status, disability, gender identity or Veteran status. We also consider qualified applicants regardless of criminal histories, consistent with legal requirements. See ...
#  '  Company Description  The Department of Technology is the centralized technology services provider within San Francisco City & County government, delivering technology infrastructure and services approximately 33,000 employees and 800,000 residents. The department has an annual operating budget of over $130M and contains over 260 employees. Core service areas include: Infrastructure and Operations, Technology Security, Service Delivery & Management, Enterprise Applications, Project Management Office, Public Safety Systems & Wiring, Technology Administration, Policy & Governance and IT Public Communications.  If you are interested in a position where your leadership, expertise problem solving is valued, please consider joining DT. We are passionate about public service and contribute a diverse range of perspectives and ideas for improved technology services. Join us as we solve exciting challenge and push the boundaries of what technology can do for San Francisco\\\'s 33,000+ City employees and 800,000+ residents.    Job Description     Provide Service IT support requests for the Department of Technology including end user support of standard applications and equipment.  Provide point of escalation for junior 1092\\xe2\\x80\\x99s and may help coordinate workloads among the team as well as develop staff professional growth.  May provide initial service a more technical or complex (technically or professionally) request.  Manage Endpoints (WKS and SVR) using the Department\\xe2\\x80\\x99s Endpoint management Systems, System Patching, System Backups, System Imaging, hardware deployment and inventory, remote control support and track client Department configuration.  Manage application lifecycle management; maintain up to date application libraries.  Develop, design, and implement problem solutions.  Monitor and track actionable notifications from our Monitoring and ticketing system.  Onboard and Offboard employees following appropriate SOP.  Contributing to planning equipment and software choices for a department.  Contribute to DR testing, planning, and execution when appropriate.   Job Type:  We are hiring one (1) Permanent Exempt and one (1) Temporary Exempt - Full Time position. Both of them are excluded by the Charter from the competitive civil service examination process and shall serve at the discretion of the appointment officer. The anticipated duration of this project position is thirty-six (36) months and will not result in an eligible list or permanent civil service hiring.  Nature of Work:  Incumbent must be willing to work a 40-hour week as determined by the department. On-call support and occasional weekend work is required. Travel within San Francisco may be required.  Work Location:  Incumbent will conduct the majority of work at the Department of Technology, One South Van Ness Avenue, 2nd Floor. However, there may be situations where the incumbent will be required to work at other sites throughout the City of San Francisco as necessary. The department is currently working in a hybrid model; however, telecommuting options are available upon the appointing officer\\xe2\\x80\\x99s approval and at the appointing officer\\xe2\\x80\\x99s discretion.    Qualifications  Education: Requires an associate degree in computer science or a closely related field from an accredited college or university OR its equivalent in terms of total course credits/units [i.e., at least sixty (60) semester or ninety (90) quarter credits/units with a minimum of twenty (20) semester or thirty (30) quarter credits/units in computer science or a closely-related field].  Experience: Three (3) years of experience performing analysis, installation, and technical support in a network environment. Substitution: Additional experience as described above may be substituted for the required degree on a year-for-year basis (up to a maximum of two (2) years). One (1) year is equivalent to thirty (30) semester units / forty-five (45) quarter units with  ...
#  "  Helpdesk   If you are a Helpdesk with experience, please read on!    Located in San Francisco, CA we provide business checking, business lending and personal banking services to underserved groups in the Mission District and surrounding neighborhoods in the San Francisco Bay Area, including minority owned small businesses and niche retailers. Our vision is to promote economic growth and stability in the underserved communities we serve by providing high-quality business and consumer financial services.   What You Will Be Doing   You should have:    3-5 years of experience with computer systems support, server installation and support, network administration, network installation, and configuration  Thorough working knowledge of Microsoft Office and Windows Operating Systems  Active Directory, Windows Servers, Desktop support/service  Experience installing software, patches, and updates on desktops, Laptops, and Servers  You will be that added support when it comes to technical issues (software/hardware related)  Having Fiserv experience is a huge plus, but not required    We are looking for someone with this experience, but also want you to be a team player! Being a small bank with a small team, we work best with people who are open minded, eager to learn, and have excellent communication and verbal skills. What matters most to us is that you understand that there will be times of busyness, times you might have to stay after hours, or a weekend every blue moon. If this is something you are willing and able to handle, the opportunity for growth is amazing. We promote within, meaning if you aspire to be in leadership this is the place for you.   What You Need for this Position   Bachelor\\'s Degree preferred - not required  Banking experience would be a huge plus, but not required  Experience with System Administration/Helpdesk duties  Software, Hardware, Security, Networking experience  Fiserv - huge plus but not required    Please have at least 3 years or more of experience to be considered.   What\\'s In It for You   Competitive Base Salary!  Medical/Dental/Vision  401K  PTO and Holidays  Possible Bonuses  Opportunities for Leadership!    Apply today!      Applicants must be authorized to work in the U.S.   CyberCoders, Inc is proud to be an Equal Opportunity Employer    All qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national origin, disability, protected veteran status, or any other characteristic protected by law.     Your Right to Work \\xe2\\x80\\x93 In compliance with federal law, all persons hired will be required to verify identity and eligibility to work in the United States and to complete the required employment eligibility verification document form upon hire. ",
#  '  Company Description  This announcement has been extended to accept additional applications.  At the San Francisco Human Services Agency we believe in a San Francisco where everyone has the opportunity and support to achieve their full potential. We are comprised of three city departments\\xe2\\x80\\x94Department of Benefits and Family Support, Department of Disability and Aging Services, and the Office of Early Care and Education\\xe2\\x80\\x94 and are united by our commitment to deliver essential services that support and protect people, families, and communities.  From financial, nutritional and employment support to protective services, health care coverage, affordable childcare, and in-home services for older adults and persons with disabilities, our team lends support for all in need. Our Commitment to Racial Equity  As we work towards our vision of an inclusive San Francisco, we embrace our responsibility to root out systemic racism by creating services and a workforce which reflect the lived experiences and strengths of the people we serve. We are committed to fostering a work environment where our differences are celebrated and everyone has what they need to thrive-no matter their race, age, ability, gender, sexual orientation, ethnicity, or country of origin. Click here to learn more about what this commitment looks like in action.    Job Description  Under general direction, the IS Business Analyst participates in the systems development lifecycle, including project planning and management, as well as business process redesign. Specifically, the incumbent will be responsible for managing or assisting with the management of web and / or mobile development projects. The incumbent will collaborate with select programs to identify business needs and business processes that will either be introduced or modified for their assigned projects. The process for gathering and documenting requirements, translating requirements to functional requirements and application testing are core responsibilities of the IS Business Analyst. The individual will also be responsible for coordinating system implementations, managing user acceptance testing, system testing, end user training, production support, and performing other related duties as assigned.  Under general direction, the 1052 IS Business - Analyst performs the following essential duties and functions:   Identify opportunities for improving business processes through automation; assist in the preparation of proposals to develop new systems.  Determine operating characteristics and requirements; develop or modify and document general system design; write detailed design specifications including requirements documents, functional specifications, and test cases; conduct "walkthroughs" for proposed solutions to system problems.  Analyze the feasibility of and develop requirements for enhancements to existing systems; ensure the system design fits the needs of the users.  Provide technical support for web application and mobile application systems; consult on the analysis of an application; troubleshoot system problems; assist with the implementation of solutions.  Conduct system analysis and may conduct programming activities for complex systems; document new and modified systems and programs  Coordinate user training in new capabilities  May assist with the conversion from test to production.  Interface with users to determine system needs and requirements  Review impact of system modifications on existing systems.  Prepare, or assist client in preparing, service requests to implement system changes  Determine, or assist in determining, level of effort required and the cost of implementing service requests; assist in prioritizing requests.  May provide technical production support for application systems; assist with processing schedule  Determine security levels for systems to ensure data integrity.  Create test scenarios, test cases, UAT scripts, and other testing documentat ...
#  "   Disruptive Games is a veteran development studio specializing in multiplayer and online experiences. We are an independently owned studio working on a  AAA, fully-funded title with original IP!     We\\xe2\\x80\\x99re expanding our  fully-remote team with people who share our passion for collaborative, multiplayer gameplay.     Disruptive is looking for an  IT Support Specialist to join our growing team! In this position, you\\xe2\\x80\\x99ll be the first point of contact and trusted resource for all things systems, hardware, and software.   What You\\'ll Do   Assist in the new hire onboarding process by enrolling team members in our internal systems (Google, Azure, etc)  Own end-to-end management of systems access, partnering closely with Operations and People Operations  Manage all software and hardware licensing, including purchasing and renewals  Implement and advise on security policies, internal IT audits, and ongoing security trainings  Create and maintain internal documentation on Helpdesk and IT policies and user support  Monitor and maintain records of equipment assets and software tracking  Support and drive integration and automation projects to help our team scale and optimize for efficient work  Manage the set up, configuration, and upgrades required to maintain team equipment  Assist with the offboarding process, including system and asset management   What You\\'ll Bring   3+ years of experience in an IT Support or Helpdesk function  Ability to communicate knowledgeably, clearly, and compassionately with all team members  Experience in building IT knowledge bases and developing and executing on policies  In-depth practical knowledge and troubleshooting ability in common technical systems  Experience working in a remote environment    Disruptive Games is an Equal Opportunity Employer. We recruit, interview, and hire people of all backgrounds, orientations, identities, and expressions.  ",
#  ' Fully remote Need to be strong in scrum/agile Managing multiple scrum teams 3-4 yeas of exp Working on major implementations. Able to manage max team capacities JIRA exp is a need Able to create dashboards and reporting Healthcare exp is not required Degree not required Salesforce exp is a nice to havePotential to extend right now. Job Type: Full-time Schedule:  Monday to Friday Ability to commute/relocate:  San Francisco, CA: Reliably commute or planning to relocate before starting work (Preferred) Experience:  Scrum: 3 years (Preferred) License/Certification:  PMP (Preferred) Work Location: One location',
#  '  IT Support Engineer   If you are an IT Support Engineer with Active Directory/O365 experience, please read on!    We are headquartered in the San Francisco, CA area (94105) area and we are cutting edge healthcare data analytics company that has become one of the most reputable companies in our space! We have been in business for over 20 years and have expanded to over 500 employees nationwide. We were recently recognized as one of the top places to work in the nation and pride ourselves in our excellent work-life balance.    We are looking for a skilled IT Support Engineer to support both a local and remote team. This person will provide first/second level contact and IT support and resolve technical issues for internal customers. This person will Install/upgrade/support Windows 10, Microsoft Office and other business applications as well as use diagnostic tools to trouble shoot problems.   Top Reasons to Work with Us   Excellent work life/balance  HUGE room for growth  Great benefits  Full-time, perm position with bonus and 401k   What You Will Be Doing   Providing first/second level IT Support  Install/upgrade/support Windows 10, Microsoft Office and other business applications  Use diagnostic tools to trouble shoot problems  Work with Active Directory and O365   What You Need for this Position   At least 3-4 years of experience with:        Active Directory  Office 365    Nice to haves:        PC Hardware  GPO  LAN/WAN  VPN  Azure AD      So, if you are an IT Support Engineer with Active Directory/O365 experience, please apply today!      Applicants must be authorized to work in the U.S.   CyberCoders, Inc is proud to be an Equal Opportunity Employer    All qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national origin, disability, protected veteran status, or any other characteristic protected by law.     Your Right to Work \\xe2\\x80\\x93 In compliance with federal law, all persons hired will be required to verify identity and eligibility to work in the United States and to complete the required employment eligibility verification document form upon hire. ',
#  "  Note: Google\\xe2\\x80\\x99s hybrid workplace includes remote and in-office roles. By applying to this position you will have an opportunity to share your preferred working location from the following:    In-office locations: Mountain View, CA, USA; San Francisco, CA, USA.   Remote location(s): United States.  Minimum qualifications:    Bachelor\\xe2\\x80\\x99s degree or equivalent practical experience.  8 years of experience in program or project management.  5 years of experience in a people management role.   Preferred qualifications:    8 years of experience managing cross-functional team projects.  Experience in data analytics and visualization.  Experience in a high-tech industry with direct product development, program management, project management, professional services or engineering management.    About the job  A problem isn\\xe2\\x80\\x99t truly solved until it\\xe2\\x80\\x99s solved for all. That\\xe2\\x80\\x99s why Googlers build products that help create opportunities for everyone, whether down the street or across the globe. As a Program Manager at Google, you\\xe2\\x80\\x99ll lead complex, multi-disciplinary projects from start to finish \\xe2\\x80\\x94 working with stakeholders to plan requirements, manage project schedules, identify risks, and communicate clearly with cross-functional partners across the company. Your projects will often span offices, time zones, and hemispheres. It\\'s your job to coordinate the players and keep them up to date on progress and deadlines. Our goal is to build a Google that looks like the world around us \\xe2\\x80\\x94 and we want Googlers to stay and grow when they join us. As part of our efforts to build a Google for everyone, we build diversity, equity, and inclusion into our work and we aim to cultivate a sense of belonging throughout the company.   The Google Nest dogfood team is growing! We\\'ve launched the Google Nest Displays, Google Home, Mini, Max and Home Hub, Google Nest Renew, Google Nest Hello, Cameras, Protect, Sensors, Thermostats and Secure, Chromecasts, Google Wifi and more, and are busy working on more incredible products!   As a Program Manager, you will drive planning and cross-functional execution of critical programs, and strategic initiatives. You will develop plans and recommendations that influence the actions of cross-functional teams and leadership teams.   Additionally, you will manage products through the development, dogfood and launch cycle. You will coordinate many fast-changing, moving parts, advocate for the users, and drive key bugs and pain points to closure with our Product teams.  Google\\'s mission is to organize the world\\'s information and make it universally accessible and useful. Our Devices & Services team combines the best of Google AI, Software, and Hardware to create radically helpful experiences for users. We research, design, and develop new technologies and hardware to make our user\\'s interaction with computing faster, seamless, and more powerful. Whether finding new ways to capture and sense the world around us, advancing form factors, or improving interaction methods, the Devices & Services team is making people\\'s lives better through technology.     Additional Information   (Colorado only*) Minimum salary range between $169,000 - $181,000 + bonus + equity + benefits.        Note: Disclosure as required by sb19-085 (8-5-20) of the minimum salary compensation range for this role when being hired into our offices in Colorado.        Responsibilities    Manage a team of Dogfood Program managers, creating inclusive environment, standardization, and scale.   Work and communicate cross-functionally with Program Management, Legal, Compliance, Engineering, Product Management, Operations, and external partners.   Manage the day-to-day running of multiple projects, identify dependencies and manage risks, key timelines, and stakeholders to remove roadblocks and keep processes running smoothly.   Use data, internal tools, a ...
#  ' ***This position is not eligible for sponsorship*** Link to apply directly: https://eeho.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1/job/147139/?utm_medium=jobshare Manages a team maintaining and/or implementing software project(s) and/or internal systems. Defines, documents and manages scope, expectations, implementation approach, deliverables and acceptance testing criteria. Leads a specialized area that may have diverse functional elements. Frequently interacts with Executives and/or functional peer group managers. May interact with senior management. Demonstrated leadership skills. Detailed knowledge of several applications within a business area is needed. BA/BS degree and relevant experience. Responsibilities:  Manages ALL Executive level Video Conferencing at the Customer Visit Centers and Virtual Events. First Line Technical and Customer Support for the Customer Visit Center. Maintain and troubleshoot all Audio-Visual Presentation Systems and Infrastructure. Troubleshoot basic PC/Laptop problems for our customers to include connectivity and presentation-related issues. Maintain and Troubleshoot the Center\\xe2\\x80\\x99s PCs/Systems and Network Infrastructure Monitor all activity on the main floor while providing excellent customer service for Customers, Sales Teams, and staff Responsible for day-to-day operations and floor management Responds promptly to all general phone calls at the center Keeps CVC floors secure and monitors restricted access Provides opening/closing day procedures and room setups Greet Customers at arrival and assist with questions and requirements throughout the day Assist Sales Teams on day-of Customer Visits Assist with Customer concierge requirements Communicate critical information to sales reps, presenters, catering and conference center staff Monitor agendas to ensure meetings/briefings arrive on time and/or advises if running behind schedule Monitor and Maintain all Digital and Welcome signage boards Serve as Technical Support, Security and Operations liaison for day-of activity Digital Media Administration:  Expert Administrator for Digital Media (DM) Platform: Manages all Global Customer Visit Center and Conference Center\\xe2\\x80\\x99s Digital Media System and Infrastructure. Maintain, Monitor, Support, and Troubleshoot all Digital Media Systems and Infrastructure. Translates Marketing, CVC, and Branding Business Requirements to Programmable Media Design Develop Templates and Show Flows for all DM Formats: Agenda Monitors, Welcome Boards, Dashboards, and Video Walls. Create, Define, and Maintains User Roles: Administrator, Regional, Local and Site roles Multi-Media Interactive Wall Administration:  Expert Administrator for Interactive Media Video Wall. Manages all customized interactive video wall infrastructure in the Customer Visit Center and the Conference Centers. Provides day-to-day maintenance and support. Technical Liaison for Oracle to our third-party provider Downstream and key stakeholders and LOBs. Technical Expertise: Assist in designing how content is accessed and displayed on the interactive walls. Provides demonstrations to all our customers Key Technical Skills:  PC/MAC Systems Administration, Networking, Linux/Unix Administration AV Equipment: Crestron, Audio Processors, Visual Display Equipment Digital Media Administration (Fourwinds) Qualifications: A minimum of three years of experience supporting medium to large applications, working directly with internal/external clients, and one to two years experience providing user support of PC/Windows network custom business applications preferred. Experience with Microsoft Windows and MS Office applications, specifically EXCEL, Word, PowerPoint. Ability to develop a working knowledge of assigned company products, interact effectively with other technical and non-technical resources, and quickly establish comfortable and effective working relationships. Demonstrate ability to analyze and evaluate comple ...
#  "  Company Description  This is a Position-Based Test conducted in accordance with CSC Rule 111A.   Application Opening \\xe2\\x80\\x93 April 22, 2022  Application Deadline \\xe2\\x80\\x93 May 6, 2022  Application Extended Deadline - May 20, 2022  Second Extended Deadline - June 10, 2022  Compensation: $100,776.00-$126,854.00 Yearly  Class Description: https://www.jobapscloud.com/SF/specs/classspecdisplay.asp?ClassNumber=1063  List ID: PBT-1063-118695; 1120198   At the San Francisco Human Services Agency, we believe in a San Francisco where everyone has the opportunity and support to achieve their full potential. We are comprised of the Department of Benefits and Family Support, and the Department of Disability and Aging Services, and are united by our commitment to deliver essential services that support and protect people, families, and communities.  From financial, nutritional and employment support to child and adult protective services, health care coverage, affordable childcare, and in-home services for older adults and persons with disabilities, our team lends support for all in need.  Our Commitment to Racial Equity As we work towards our vision of an inclusive San Francisco, we embrace our responsibility to root out systemic racism by creating services and a workforce which reflect the lived experiences and strengths of the people we serve. We are committed to fostering a work environment where our differences are celebrated and everyone has what they need to thrive-no matter their race, age, ability, gender, sexual orientation, ethnicity, or country of origin. Click here to learn more about what this commitment looks like in action.    Job Description  According to Civil Service Commission Rule 109, the duties specified below are representative of the range of duties assigned to this job class and are not intended to be an inclusive list.  Under general direction, the 1063 IS Programmer Analyst-Principal performs the following essential duties and functions:   Determine testing requirements for new systems and enhancements to existing systems; develop or modify and document general system design; establish a production environment and migrate approved programs to production.  Design and code programs with a high level of complexity; prepare comprehensive test plans and ensure that programs are tested; implement new programs.  Ensure program specifications are complete; produce basic components, such as program overview, listing of files and related programs and sub-programs, charts and screen flow diagrams and the like, to ensure complete programming; review specifications submitted by vendors to ensure the specifications are in line with department standards and policies  Develop and assist with implementing new testing standards, testing processes, release standards, and testing policies  Analyze, research and repair program logic and systems; modify program logic.  Test new software technologies; report results; recommend software purchases, and implement new software as needed  Conduct application testing, analyze results, create reports with results, provide recommendations on fixes for identified issues  Train users on procedures and applications; provide technical assistance on the use of systems.  Meet with users to discuss testing needs and requirements in order to prepare a comprehensive testing plan.  Create test scenarios, test plans, and test cases; execute unit test and document results; assist users to develop and execute system test; provide migration support to uers; resolve problems. Create timelines and schedules for projects.  Identify opportunities for operational improvements; participate in special projects as necessary.  Assess production problems; prioritize needs; resolve problems.  Document program specifications, structure charts, job-control procedure listings, test data listings, test run output, input/output data specifications and the like.  Prepare user and technical manuals and inst ...
#  '  The mission of The New York Times is to seek the truth and help people understand the world. That means independent journalism is at the heart of all we do as a company. It\\xe2\\x80\\x99s why we have a newsroom that\\xe2\\x80\\x99s 1,700 strong and sends journalists to report on the ground from nearly 160 countries. It\\xe2\\x80\\x99s why we focus deeply on how our readers will experience our journalism, from print to audio to a world-class digital and app destination. And it\\xe2\\x80\\x99s why our business strategy centers on making journalism so good that it\\xe2\\x80\\x99s worth paying for.   Note for US based roles: Any offer of employment is contingent on providing proof of Covid-19 vaccination prior to your start date, subject to approved medical and/or religious exemptions, in accordance with applicable law.     The Technical Support Specialist position provides infrastructure IT support services for The New York Times Company. This role will be supporting all functional business areas, working closely with the New York Help Desk, networking, storage, and other support teams to provide fast and seamless service to end users.  Responsibilities include:   Provide hands on support to business critical end-users on the macOS and Windows platforms.  Enforce standards and security, including but not limited to, PCI and GDPR compliance standards.  Handle IT support requests via ServiceNow and Jira ticketing systems providing resolution in a timely manner within a complex, fast-paced business environment.  Deploy, configure, and troubleshoot end user computing devices including, laptops, desktops, printers, monitors, video conferencing equipment, and wireless devices.  Maintain all equipment per the company inventory asset control standards.  Install, configure, and troubleshoot supported operating systems and applications including but not limited to Microsoft Office, Adobe Creative Suite, financial tools and internet browsers.  Provide customer training on systems and technology to end users and, as needed, prepare and distribute instructional documentation to users.  Troubleshoot incidents and fulfill requests in accordance with established departmental standards including supporting ITIL change-incident-problem management processes and work instructions.  Work with approved vendors for both IT and non-IT requests to support business requirements.  Help support remote offices as needed which may require travel (domestic and international).  Handle projects assigned by management.  Work independently on day-to-day operations.  Support special events in the office and at remote locations.  Perform related work as assigned.    Requirements:   Minimum 3 years of experience in an information technology technical support role.  Experience with end user support of a wide range of technology.  Experienced system administrator.  Familiarity with networking concepts preferred.  Strong written/verbal communication skills.  Ability to perform in a dynamic environment with changing schedules and priorities.  Ability to travel (domestic and international) preferred.  Entrepreneurial spirit.  Excellent customer focus.  Self-motivated.  Ability to work a hybrid in-office/remote work schedule.    #LI-AM1   The New York Times is committed to a diverse and inclusive workforce, one that reflects the varied global community we serve. Our journalism and the products we build in the service of that journalism greatly benefit from a range of perspectives, which can only come from diversity of all types, across our ranks, at all levels of the organization. Achieving true diversity and inclusion is the right thing to do. It is also the smart thing for our business. So we strongly encourage women, veterans, people with disabilities, people of color and gender nonconforming candidates to apply.   The New York Times Company is an Equal Opportunity Employer and does not discriminate on the basis of an individual\\\'s sex, age, race, color, creed, n ...
#  '  Starting your career in Investment Banking Division as an Analyst, you will be a key player in the execution of the firm\\\'s business. You will work with expert professionals at the heart of a leading global investment bank. Senior bankers will get to know you - both as a person and as a valued member of a winning team. You will experience training, hands-on learning opportunities, continuous mentoring and feedback, and numerous development opportunities. You will use your related experience to contribute to the firm\\\'s M&A execution and capital raising capabilities while helping build J.P. Morgan\\\'s franchise and reputation in the marketplace. You will develop strong functional skills in the major areas of investment banking and become a senior client executive who is capable of generating and executing your own transactions. Joining here means you\\\'ll become part of our inclusive teams and culture, unified by the firm\\\'s mission and commitment to success.  This role requires a wide variety of strengths and capabilities, including:    Prior work experience in an investment banking front office, or related, role.  Strong accounting, finance, quantitative and business writing skills.  A well-rounded academic background  Understands transaction cycle and the steps in the process and is execution oriented.  Impeccable communication details with the ability to effectively interact with senior professionals, clients and key stakeholders in other line of business.  Self-directed, highly motivated, and able to work independently   Investment Banking (GIB)  Within Investment Banking, the firm works with a broad range of issuer clients, including corporations, institutions and governments, to provide comprehensive strategic advice, capital raising and risk management expertise. In-depth, industry-specific expertise and regional market acumen enable our industry coverage teams to serve the evolving needs of clients around the world. Our first-class business in a first-class way approach to serving clients drives everything we do. We strive to build trusted, long-term relationships by taking a holistic and forward-looking view on our relationships, and identifying ways to help clients achieve their most important business objectives.  About J.P. Morgan\\\'s Corporate & Investment Bank  J.P. Morgan\\\'s Corporate & Investment Bank is a global leader across banking, markets and investor services. The world\\\'s most important corporations, governments and institutions entrust us with their business in more than 100 countries. With $24 trillion of assets under custody and $420 billion in deposits, the Corporate & Investment Bank provides strategic advice, raises capital, manages risk and extends liquidity in markets around the world.  JPMorgan Chase & Co., one of the oldest financial institutions, offers innovative financial solutions to millions of consumers, small businesses and many of the world\\\'s most prominent corporate, institutional and government clients under the J.P. Morgan and Chase brands. Our history spans over 200 years and today we are a leader in investment banking, consumer and small business banking, commercial banking, financial transaction processing and asset management.  We recognize that our people are our strength and the diverse talents they bring to our global workforce are directly linked to our success. We are an equal opportunity employer and place a high value on diversity and inclusion at our company. We do not discriminate on the basis of any protected attribute, including race, religion, color, national origin, gender, sexual orientation, gender identity, gender expression, age, marital or veteran status, pregnancy or disability, or any other basis protected under applicable law. In accordance with applicable law, we make reasonable accommodations for applicants\\\' and employees\\\' religious practices and beliefs, as well as any mental health or physical disability needs.  The health and sa ...
#  "  Remote role - West Coast  Position Summary: This is a full-time position that reports to the IT Service Desk Manager. As part of a global team, this individual will provide support to our employees worldwide. The position requires strong customer service skills, the ability to stay organized, and solid problem-solving skills.  What You\\'ll Do Frontline incident and request management:    Monitor the ticketing system for incoming incidents/requests  Log and track all issues (example: phone, email, IM, walk-ups, and any other methods)  Log and track all security-related issues (example: phishing emails)  Troubleshoot and address issues directly; workstation issues, basic network issues (local network, Internet, Wi-Fi)  Take ownership of tasks/projects and represent the user to ensure the requests are processed  Communicate to the end-user on progress promptly  Document issues, analysis, progress, solution in the ticketing system   Training To Users    Assist with onboarding/offboarding of employees  Provide basic in-house training of tools and applications; MS Office, Video Conferencing (ZOOM, Polycom, etc.), and collaborations suite (OneDrive, O365 groups, etc.)   Workstation Setup Management    Setup and deployment for new employees using standard hardware, images, and software (Windows & Mac OS X)  Modify configurations, utilities, software default settings, etc. for the local workstation   Office Support / AV    Manage Audio/Video equipment (microphones, cameras, etc) for meetings  Assist and troubleshoot on IT-related equipment: phone system, videoconference system, mobile devices   Local Asset Management    Manage asset inventory and anticipate hardware needs  Proactively identify the end of life user workstations and coordinate replacement   Who you are    3+ years experience in IT Service desk environment, in a fast-paced though structured environment  Self-Motivator; able to work alone and take ownership of responsibilities  Be able to prioritize and follow up issues with method and efficiency  Strong communication and reporting skills  Master of autonomy  Advanced knowledge of Microsoft based software; Windows 10 and Office 365  Experience with using and troubleshooting Outlook within a network environment (permissions, calendar sharing, delegation)  Good knowledge and experience of mobile devices (iOS, Android, etc.) for system configuration (email settings, certificates deployment, application installation, etc.)  Good knowledge and experience of Apple Mac OS X, within a Windows environment (Active Directory integration, File/Print server, etc.)  Understanding of network configuration on workstations (DNS, TCP/IP, and other networking concepts)  Ability to write technical documentation to feed the Service desk knowledge database  Attention to detail, ability to follow detailed instructions and make independent judgments, and strong technical analytic abilities  Experience in meeting the demands of complex production-oriented environments where timeliness and availability of information are considered critical.  Must be able to work effectively to resolve problems under fast pace conditions in a high demand environment  Aptitude for learning new software through manuals, the Internet, and trial-and-error.  Triage work as necessary for self and other IT staff  Act as a further escalation point for unresolved or escalated tickets  Provides instructions to new and current team members on features, capabilities, and policies  Report to management on any issue that could significantly impact the business  Tier 1 and tier 2 systems implementation, troubleshooting, and analysis  Researches, test, and assesses new technologies for potential use and implementation  Assists IT Management, with technical duties and high-level projects      Competencies    Customer Focus \\xe2\\x80\\x93 Building strong customer relationships and delivering customer-centric solutions  Drives Results \\xe2\\x80\\x93 Consistently achieving resu ...
# ...
#  "  The University Paging Services Team in Client Experience and Solutions (CXS) is seeking a new IT Business Analyst to join our team. We primarily answer calls and address tickets from the University, Stanford Health Care, and Stanford Children\\xe2\\x80\\x99s Hospital communities for a variety of Stanford Paging Service needs. We pride ourselves on providing exceptional customer service to all of our clients.    If you are experienced in customer service, can stay calm under pressure, and are a phenomenal teammate, this may be the role for you!    JOB PURPOSE:  Under direct supervision, provide technical and non-technical support to end-users for all levels of paging services subject but not limited to: paging operations, paging communications for Stanford hospital and Stanford University, and order processing. Responsible for supporting Mobile device department with staffing, service delivery, and client satisfaction.    CORE DUTIES:   Process new or replacement paging request from internal and external clients  Manage and maintain SPOK wireless devices through internal SPOK portal in its entirety. Subject but not limited to device returns, cancels, new services, activations, contact information, and department information.  Utilize paging internal management system to enroll physicians, staff, and medical students with paging services  Collaborate cross-functionally with internal and external teams  Troubleshoot and support paging devices  Responsible for billing services with paging through ServiceNow  Diagnose and resolve end user problems; response to escalated issues from clients and other support teams; perform triage, provide remote problem resolution when possible.  Maintain all current documentation to knowledge base articles  Manage Paging services page content to ensure accuracy and service excellence  Other relevant duties may be assigned      MINIMUM REQUIREMENTS:    Education & Experience: Bachelor\\'s degree and three years relevant experience or a combination of education and relevant experience.       Knowledge, Skills and Abilities:    Strong communication and interpersonal skills   Ability to provide excellent client and end user experience   Experience with ServiceNow a plus   Ability to apply information technology best practices, including security (this includes information security or physical security, such as asset management) to problem and resolution troubleshooting       Certifications and Licenses:    None       PHYSICAL REQUIREMENTS:*    Constantly perform desk-based computer tasks.   Frequently sitting, using a telephone, grasping lightly/fine manipulation, bending, lifting, standing, and carrying equipment.   Occasionally stand/walk, use a telephone.   Rarely writing by hand, lift/carry/push/pull objects that weigh up to 10-20 pounds.         Consistent with its obligations under the law, the University will provide reasonable accommodation to any employee with a disability who requires accommodation to perform the essential functions of the job.       WORKING CONDITIONS:    Paging Services hours are 8am-5pm (PST) Monday through Friday.   Hybrid workplace: onsite Stanford Healthcare location and remote       WORK STANDARDS:    Interpersonal Skills: Demonstrates the ability to work well with Stanford colleagues and clients and with external organizations.   Promote Culture of Safety: Demonstrates commitment to personal responsibility and value for safety; communicates safety concerns; uses and promotes safe behaviors based on training and lessons learned   Subject to and expected to comply with all applicable University policies and procedures, including but not limited to the personnel policies and other policies found in the University\\xe2\\x80\\x99s Administrative Guide, http://adminguide.stanford.edu.       WHY STANFORD IS FOR YOU:  Stanford University has revolutionized the way we live and enrich the world. Supporting this mission is our diverse and dedicated 17,000 staff. We seek tale ...
#  ' Director of eCommerce Product Management AKRE & Associates San Francisco, California, United States (Hybrid) We are recruiting for a passionate Web/eCommerce Product leader who is highly focused on great customer experiences. Our client is a fast-paced, creative, collaborative, global organization committed to creating strong digital strategies and programming. This leader will be strategy-minded; laser-focused on roadmaps, deadlines, and deliverables. An entrepreneurial mindset is a MUST! Implementing across global platforms, advocating for the \\xe2\\x80\\x9cvoice of the customer\\xe2\\x80\\x9d and pushing the limits both internally and externally is critical. This leader must be comfortable making data-driven decisions with a user-experience approach and a high level of collaboration. Responsibilities: \\xc2\\xb7 Develop & execute website and platform strategy \\xc2\\xb7 Collaborate with cross-functional partners and vendors on bringing brand, voice, and products to life across multiple websites \\xc2\\xb7 Oversee advancements in the eCommerce and digital space, as well as the competitive landscape, for new ideas to improve our customer experience \\xc2\\xb7 Partner with analytics on A/B testing, pre/post analyses, and site satisfaction measures to drive the roadmap \\xc2\\xb7 Manage web content calendar and operations \\xc2\\xb7 Oversee the development cycle (developers, QA, external vendors) on continuous feature updates and releases. \\xc2\\xb7 Partner with engineering to assess architecture, tools, vendors, and technical solutions \\xc2\\xb7 Ensure stakeholders and web teams are communicating and collaborating \\xc2\\xb7 Champion customer and stakeholder needs \\xc2\\xb7 Measure and report on timelines, quality, site KPIs, customer feedback, usability, and site testing results Requirements: \\xc2\\xb7 5+ yrs B2C eCommerce product management experience \\xc2\\xb7 Global platform exposure \\xc2\\xb7 Proven track record of managing numerous priorities and spearheading multiple projects simultaneously \\xc2\\xb7 Strong experience working with web content tools and/or development teams \\xc2\\xb7 Strong analytical skills to make data-driven decisions \\xc2\\xb7 Content and SEO experience preferred Job Type: Full-time Pay: $200,000.00 per year Benefits:  401(k) Dental insurance Health insurance Paid time off Schedule:  Monday to Friday Supplemental Pay:  Bonus pay Work Location: One location',
#  '  Disney Streaming is responsible for developing and operating The Walt Disney Company\\xe2\\x80\\x99s direct-to-consumer video businesses globally, including Disney+, Hulu, ESPN+, and Star+. We serve consumers by bringing the world\\xe2\\x80\\x99s most beloved characters, timeless stories, legendary athletes, and epic sporting events to global audiences through best-in-class direct-to-consumer video services. Our core mission is to imaginatively challenge convention with innovative technology that gives global audiences the freedom to access content on their terms across any connected device, time, or location.   The Edge Operations team\\xe2\\x80\\x99s mission is to provide resiliency and availability of critical infrastructure in our various data centers and co-locations that power the media distribution of all of Disney Streaming\\xe2\\x80\\x99s world-class products.   For the role of Senior Network Operator, Disney Streaming is looking for a candidate specializing in caching technology and distributed networking, and operational experience in CDN edge services. This role will join the Media Systems Operations organization as part of a team working alongside our Operations, Infrastructure, and Media Distribution teams in managing our growing caching infrastructure. Areas of focus include:   Provide senior tier-1 on call evaluation, escalation and support  Actively monitor performance metrics across our caching infrastructure for issues  Work to solve caching issues in concert with our edge engineering organization  Participate in tooling development to automate and improve lifecycle and operational management of caching environment  Point of contact for CDN edge services operations; collaborating with operations and infrastructure organizations as needed  Design and develop procedures to make preemptive and immediate corrective actions that minimize risk    Responsibilities :     Monitor for and react to alerts within the CDN edge services environment providing senior tier-1 support  Provide clear communication/escalation/follow up/closure of alerts and maintenances to teams within the organization  Collaborate with engineering and internal teams involved with maintaining our server infrastructure  Write and improve team knowledgebase  Support high profile content releases and events    Basic Qualifications :     At least 5 years of related experience  In-depth knowledge of HTTP/DNS/Internet architecture  Understanding of HLS streaming video protocol and how it interacts with caching  Experience in CDN operations environments  Familiarity with web servers, preferably NGINX and HAProxy  Experience working with Varnish Cache  Experience with open-source software Apache HTTP Server, Tomcat, and Traffic Control  Knowledge of video players and impact on cache logic  Experience with monitoring tools, preferably Grafana, Datadog  Strong operational experience  Passion for troubleshooting and debugging  Excellent interpersonal skills and effective verbal/written communication skills with both business and technical teams  Experience using JIRA, Confluence, and GitHub    Preferred Qualifications:     Familiarity with cloud technologies AWS, GCP  Experience working with ELK Stack for log analysis  Familiarity with DevOps/CI/CD and automation software Ansible  Familiarity with Python scripting language    Preferred Education :     BS/BA  ',
#  " We are looking for a software engineer who is passionate about privacy to ensure Infinitus products and services protect user privacy by designing architecture, tools and features. At Infinitus, we encourage all engineers to take ownership over technical and product decisions, closely interact with users to collect feedback, and contribute to a thoughtful, dynamic team culture. At Infinitus, you will:  Work at a cutting edge conversational AI company. Discover and document the ways that data is collected, processed and stored across our products and infrastructure to ensure our data collection and usage practices are transparent, protect user privacy, and mitigate risk. Lead and manage development of new privacy features, tools, and scalable solutions. Embed with engineering and product teams during development to ensure our data collection and usage practices are transparent, protect user privacy, and mitigate risk. Conduct technical, product, and policy reviews for new products and features and identify privacy concerns and mitigations. Anonymize and pseudonymize personal data to suite Infinitus business needs while maintaining all privacy requirements. Build data labeling tools used by our data annotation team. Create and maintain the application security documentation. We are looking for someone who has:  Bachelor degree in Computer Software, Information Science, Cybersecurity or equivalent. 2+ years\\xe2\\x80\\x99 experience as a software engineer. 2+ years\\xe2\\x80\\x99 experience as a privacy engineer. Experience in privacy with one or more of the following privacy principles or technologies: privacy by design, user data protection, GDPR, CCPA, data inventory, DLP, encryption, anonymization or privacy impact assessments Experience with concepts and practices such as threat modeling, data anonymization and classification, auditing access to data, and review of requests for data access Experience with writing code in Python. Excellent collaborative skills. Excellent written and verbal communication. Nice to have:  Experience at an early-stage startup. Working knowledge of Go, Java Script or C++. What we can offer you:  Competitive salary and pre-IPO stock options 100% company-paid medical, dental and vision insurance (for employee) Flexible paid time off Leave programs for life events 401(k) Happy hours and team-building events A great company culture with a strong emphasis on diversity, equity and inclusion Infinitus Systems, Inc. is an early stage startup building a voice automation platform to enable businesses to communicate with each other efficiently. Infinitus has raised $51.4M to date and is backed by Kleiner Perkins, Coatue Management and Google Ventures. Healthcare is one of the biggest contributors to the US GDP and we are on a mission to reduce the complexity and spend on healthcare backoffices. At Infinitus, you will have a unique perspective on the development of cutting edge technology while working with major players across the healthcare industry in the US.Infinitus is made up of engineers, product managers, AI trainers, and operations specialists who collaborate on all kinds of projects. We not only encourage each other to do our best work, we also share our pet pictures, our favorite recipes, and stories from our vacations.At Infinitus Systems, we are committed to providing an environment of mutual respect where equal employment opportunities are available to all applicants and teammates without regard to race, color, religion, sex, pregnancy (including childbirth, lactation and related medical conditions), national origin, age, physical and mental disability, marital status, sexual orientation, gender identity, gender expression, genetic information (including characteristics and testing), military and veteran status, and any other characteristic protected by applicable law. Infinitus Systems believes that diversity and inclusion among our teammates is critical to our success as a global company, a ...

# %%
from blingfire import *
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from blingfire import *
#
# File /opt/homebrew/lib/python3.9/site-packages/blingfire/__init__.py:19, in <module>
#      17 # detect Mac OSX
#      18 elif platform.system() == "Darwin":
# ---> 19     blingfire = cdll.LoadLibrary(os.path.join(path, "libblingfiretokdll.dylib"))
#      20 else:
#      21 # detect linux
#      22     blingfire = cdll.LoadLibrary(os.path.join(path, "libblingfiretokdll.so"))
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py:452, in LibraryLoader.LoadLibrary(self, name)
#     451 def LoadLibrary(self, name):
# --> 452     return self._dlltype(name)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371 self._FuncPtr = _FuncPtr
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#     376     self._handle = handle
#
# OSError: dlopen(/opt/homebrew/lib/python3.9/site-packages/blingfire/libblingfiretokdll.dylib, 0x0006): tried: '/opt/homebrew/lib/python3.9/site-packages/blingfire/libblingfiretokdll.dylib' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64e')), '/usr/local/lib/libblingfiretokdll.dylib' (no such file), '/usr/lib/libblingfiretokdll.dylib' (no such file)
